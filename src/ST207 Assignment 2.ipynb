# %%
# !python -m pip install "pymongo[srv]"

from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://tuhinaanoop_db_user:RQoNTEM8lGLTvhuI@cluster0.qmxffrh.mongodb.net/?appName=Cluster0"

# Create a new client and connect to the server
# myclient = MongoClient(uri, server_api=ServerApi('1'))
myclient = MongoClient()

# Send a ping to confirm a successful connection
try:
    myclient.admin.command('ping')  # Changed from 'client' to 'myclient'
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# /Users/tarun/Prog/assignment2-at2025-snow-flake-2512-main/.venv/bin/python: No module named pip
# Pinged your deployment. You successfully connected to MongoDB!

# %% [markdown]
# Below, I used **referencing with ObjectIds** for products' relationships to suppliers and categories, as well as for employees' self-referencing manager relationship (ReportsTo). This approach was chosen because suppliers, categories, and employees are independent entities that exist separately and may be queried independently. For instance, a supplier might supply multiple products, and we may want to retrieve supplier information without always loading all their products. Using references avoids data duplication and maintains a single source of truth for each entity's information, similar to foreign keys in relational databases.
#
# In contrast, I used **embedding** for the relationship between orders and order details. Each order document contains an embedded array of OrderDetails, where each detail includes the ProductID reference, quantity, unit price, and discount. This design choice reflects the fact that order details have no meaningful existence outside the context of their parent order - they are always created, read, and managed together with the order. Embedding improves query performance since a single database operation retrieves the complete order with all its line items, avoiding the need for joins or multiple queries.
#
# The orders and products collections also reference customers and employees using ObjectIds rather than embedding complete customer or employee documents. This decision balances data consistency with performance: while orders are closely related to customers, a customer's information (such as address or contact details) may change over time, and maintaining these as references ensures any updates to customer data are immediately reflected across all their orders without requiring updates to multiple embedded copies.

# %%
db = myclient['Northwind'] 


categories = db['categories']
suppliers = db['suppliers']
customers = db['customers']
employees = db['employees']
products = db['products']
orders = db['orders']

# mapping the old CSV IDs to the new MongoDB ObjectIds - to replace foreign keys with ObjectId references

category_map = {}
for cat in categories.find():
    category_map[cat['CategoryID']] = cat['_id']

supplier_map = {}
for sup in suppliers.find():
    supplier_map[sup['SupplierID']] = sup['_id']

customer_map = {}
for cust in customers.find():
    customer_map[cust['CustomerID']] = cust['_id']

employee_map = {}
for emp in employees.find():
    employee_map[emp['EmployeeID']] = emp['_id']

product_map = {}
for prod in products.find():
    product_map[prod['ProductID']] = prod['_id']

print(f"Categories: {len(category_map)}")
print(f"Suppliers: {len(supplier_map)}")
print(f"Customers: {len(customer_map)}")
print(f"Employees: {len(employee_map)}")
print(f"Products: {len(product_map)}")

# ============================================
# Step 2: Update products with references
# ============================================

# Products reference both suppliers and categories
# We replace the integer IDs with ObjectIds

for prod in products.find():
    updates = {}
    
    if 'SupplierID' in prod and prod['SupplierID'] in supplier_map:
        updates['SupplierID'] = supplier_map[prod['SupplierID']]
    
    if 'CategoryID' in prod and prod['CategoryID'] in category_map:
        updates['CategoryID'] = category_map[prod['CategoryID']]
    
    if updates:
        products.update_one({'_id': prod['_id']}, {'$set': updates})

print("\nUpdated products with supplier and category references")

# ============================================
# Step 3: Update employees with manager references
# ============================================

# Employees have a self-referencing relationship (ReportsTo)

for emp in employees.find():
    if 'ReportsTo' in emp and emp['ReportsTo'] and emp['ReportsTo'] in employee_map:
        employees.update_one(
            {'_id': emp['_id']},
            {'$set': {'ReportsTo': employee_map[emp['ReportsTo']]}}
        )

print("Updated employee reporting structure")
# ============================================
# Step 4: Update orders with customer and employee references
# ============================================

# Orders already have embedded OrderDetails from CSV import
# We just need to update the CustomerID and EmployeeID references

print("Updating order references...")

for order in orders.find():
    updates = {}
    
    # Update CustomerID reference
    if 'CustomerID' in order and order['CustomerID'] in customer_map:
        updates['CustomerID'] = customer_map[order['CustomerID']]
    
    # Update EmployeeID reference
    if 'EmployeeID' in order and order['EmployeeID'] in employee_map:
        updates['EmployeeID'] = employee_map[order['EmployeeID']]
    
    # Update ProductID references in embedded OrderDetails
    if 'OrderDetails' in order:
        updated_details = []
        for detail in order['OrderDetails']:
            if 'ProductID' in detail and detail['ProductID'] in product_map:
                detail['ProductID'] = product_map[detail['ProductID']]
            updated_details.append(detail)
        updates['OrderDetails'] = updated_details
    
    if updates:
        orders.update_one({'_id': order['_id']}, {'$set': updates})

print("Updated order references")

# Verifying

sample_prod = products.find_one()
print(f"\nSample product: {sample_prod['ProductName']}")
if 'SupplierID' in sample_prod:
    supplier = suppliers.find_one({'_id': sample_prod['SupplierID']})
    print(f"  Supplier: {supplier['CompanyName']}")
if 'CategoryID' in sample_prod:
    category = categories.find_one({'_id': sample_prod['CategoryID']})
    print(f"  Category: {category['CategoryName']}")

sample_order = orders.find_one()
print(f"\nSample order has {len(sample_order['OrderDetails'])} items")
first_item = sample_order['OrderDetails'][0]
if 'ProductID' in first_item:
    prod = products.find_one({'_id': first_item['ProductID']})
    print(f"  First item: {prod['ProductName']}")

print("\nAll relationships created successfully!")
# Out:
# Categories: 0
# Suppliers: 0
# Customers: 0
# Employees: 0
# Products: 0
#
# Updated products with supplier and category references
# Updated employee reporting structure
# Updating order references...
# Updated order references
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 111
#     108 # Verifying
#     110 sample_prod = products.find_one()
# --> 111 print(f"\nSample product: {sample_prod['ProductName']}")
#     112 if 'SupplierID' in sample_prod:
#     113     supplier = suppliers.find_one({'_id': sample_prod['SupplierID']})
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# 1B) List all product names and unit prices supplied by each company (supplier), along with the supplier's name.
# The output should have one document per supplier, with the required information.
#
# This query uses a `$lookup` aggregation stage to join the suppliers collection with the products collection based on the SupplierID reference (which we converted to ObjectIds). The `$lookup` operator works similarly to a SQL JOIN, matching each supplier's `_id` with the `SupplierID` foreign key in products. I then used `$project` with `$map` to reshape the output, extracting only the ProductName and UnitPrice fields from each matched product. The final result gives one document per supplier containing an array of all their products with names and prices, demonstrating how MongoDB handles one-to-many relationships through references.

# %%
# 1B) List all product names and unit prices by supplier

pipeline = [
    {
        "$lookup": {
            "from": "products",
            "localField": "_id",
            "foreignField": "SupplierID",
            "as": "Products"
        }
    },
    {
        "$project": {
            "_id": 0,
            "SupplierName": "$CompanyName",
            "Products": {
                "$map": {
                    "input": "$Products",
                    "as": "prod",
                    "in": {
                        "ProductName": "$$prod.ProductName",
                        "UnitPrice": "$$prod.UnitPrice"
                    }
                }
            }
        }
    }
]

result = suppliers.aggregate(pipeline)

# Print results
for doc in result:
    print(f"\nSupplier: {doc['SupplierName']}")
    print(f"Products ({len(doc['Products'])}):")
    for prod in doc['Products']:
        print(f"  - {prod['ProductName']}: ${prod['UnitPrice']}")
# Out:
# Supplier: Exotic Liquids
# Products (2):
#   - Chang: $19
#   - Aniseed Syrup: $10
#
# Supplier: New Orleans Cajun Delights
# Products (4):
#   - Chef Anton's Cajun Seasoning: $22
#   - Chef Anton's Gumbo Mix: $21.35
#   - Louisiana Fiery Hot Pepper Sauce: $21.05
#   - Louisiana Hot Spiced Okra: $17
#
# Supplier: Grandma Kelly's Homestead
# Products (3):
#   - Grandma's Boysenberry Spread: $25
#   - Uncle Bob's Organic Dried Pears: $30
#   - Northwoods Cranberry Sauce: $40
#
# Supplier: Tokyo Traders
# Products (3):
#   - Mishi Kobe Niku: $97
#   - Ikura: $31
#   - Longlife Tofu: $10
#
# Supplier: Cooperativa de Quesos 'Las Cabras'
# Products (2):
#   - Queso Cabrales: $21
#   - Queso Manchego La Pastora: $38
#
# Supplier: Mayumi's
# Products (3):
#   - Konbu: $6
#   - Tofu: $23.25
#   - Genen Shouyu: $13
#
# Supplier: Pavlova, Ltd.
# Products (5):
#   - Pavlova: $17.45
#   - Alice Mutton: $39
#   - Carnarvon Tigers: $62.5
#   - Vegie-spread: $43.9
#   - Outback Lager: $15
#
# Supplier: Specialty Biscuits, Ltd.
# Products (5):
#   - Chai: $18
#   - Teatime Chocolate Biscuits: $9.2
#   - Sir Rodney's Marmalade: $81
#   - Sir Rodney's Scones: $10
#   - Scottish Longbreads: $12.5
#
# Supplier: PB Knäckebröd AB
# Products (2):
#   - Gustaf's Knäckebröd: $21
#   - Tunnbröd: $9
#
# Supplier: Refrescos Americanas LTDA
# Products (1):
#   - Guaraná Fantástica: $4.5
#
# Supplier: Heli Süßwaren GmbH & Co. KG
# Products (3):
#   - NuNuCa Nuß-Nougat-Creme: $14
#   - Gumbär Gummibärchen: $31.23
#   - Schoggi Schokolade: $43.9
#
# Supplier: Plutzer Lebensmittelgroßmärkte AG
# Products (5):
#   - Rössle Sauerkraut: $45.6
#   - Thüringer Rostbratwurst: $123.79
#   - Wimmers gute Semmelknödel: $33.25
#   - Rhönbräu Klosterbier: $7.75
#   - Original Frankfurter grüne Soße: $13
#
# Supplier: Nord-Ost-Fisch Handelsgesellschaft mbH
# Products (1):
#   - Nord-Ost Matjeshering: $25.89
#
# Supplier: Formaggi Fortini s.r.l.
# Products (3):
#   - Gorgonzola Telino: $12.5
#   - Mascarpone Fabioli: $32
#   - Mozzarella di Giovanni: $34.8
#
# Supplier: Norske Meierier
# Products (3):
#   - Geitost: $2.5
#   - Gudbrandsdalsost: $36
#   - Flotemysost: $21.5
#
# Supplier: Bigfoot Breweries
# Products (3):
#   - Sasquatch Ale: $14
#   - Steeleye Stout: $18
#   - Laughing Lumberjack Lager: $14
#
# Supplier: Svensk Sjöföda AB
# Products (3):
#   - Inlagd Sill: $19
#   - Gravad lax: $26
#   - Röd Kaviar: $15
#
# Supplier: Aux joyeux ecclésiastiques
# Products (2):
#   - Côte de Blaye: $263.5
#   - Chartreuse verte: $18
#
# Supplier: New England Seafood Cannery
# Products (2):
#   - Boston Crab Meat: $18.4
#   - Jack's New England Clam Chowder: $9.65
#
# Supplier: Leka Trading
# Products (3):
#   - Singaporean Hokkien Fried Mee: $14
#   - Ipoh Coffee: $46
#   - Gula Malacca: $19.45
#
# Supplier: Lyngbysild
# Products (2):
#   - Rogede sild: $9.5
#   - Spegesild: $12
#
# Supplier: Zaanse Snoepfabriek
# Products (2):
#   - Zaanse koeken: $9.5
#   - Chocolade: $12.75
#
# Supplier: Karkki Oy
# Products (3):
#   - Maxilaku: $20
#   - Valkoinen suklaa: $16.25
#   - Lakkalikööri: $18
#
# Supplier: G'day, Mate
# Products (3):
#   - Manjimup Dried Apples: $53
#   - Filo Mix: $7
#   - Perth Pasties: $32.8
#
# Supplier: Ma Maison
# Products (2):
#   - Tourtière: $7.45
#   - Pâté chinois: $24
#
# Supplier: Pasta Buttini s.r.l.
# Products (2):
#   - Gnocchi di nonna Alice: $38
#   - Ravioli Angelo: $19.5
#
# Supplier: Escargots Nouveaux
# Products (1):
#   - Escargots de Bourgogne: $13.25
#
# Supplier: Gai pâturage
# Products (2):
#   - Raclette Courdavault: $55
#   - Camembert Pierrot: $34
#
# Supplier: Forêts d'érables
# Products (2):
#   - Sirop d'érable: $28.5
#   - Tarte au sucre: $49.3

# %% [markdown]
# ALTERNATIVE

# %%
# 1B) List all product names and unit prices by supplier

# Using a pipeline to extract product and supplier information
# The SupplierID is the foreign key connecting products to suppliers

pipeline = [
    {
        # Join suppliers and products collections
        "$lookup": {
            "from": "suppliers",
            "localField": "SupplierID",
            "foreignField": "_id",
            "as": "supplier_info"
        }
    },
    {
        # Flatten the supplier array to access supplier details
        "$unwind": "$supplier_info"
    },
    {
        # Select only the fields we need
        "$project": {
            "_id": 0,
            "ProductName": 1,
            "UnitPrice": 1,
            "SupplierName": "$supplier_info.CompanyName"
        }
    },
    {
        # Sort by supplier name for readability
        "$sort": { "SupplierName": 1 }
    }
]

result = products.aggregate(pipeline)

# Print each product with its supplier
for item in result:
    print(f"Product: {item['ProductName']}, Price: ${item['UnitPrice']}, Supplier: {item['SupplierName']}")
# Out:
# Product: Chartreuse verte, Price: $18, Supplier: Aux joyeux ecclésiastiques
# Product: Côte de Blaye, Price: $263.5, Supplier: Aux joyeux ecclésiastiques
# Product: Laughing Lumberjack Lager, Price: $14, Supplier: Bigfoot Breweries
# Product: Steeleye Stout, Price: $18, Supplier: Bigfoot Breweries
# Product: Sasquatch Ale, Price: $14, Supplier: Bigfoot Breweries
# Product: Queso Manchego La Pastora, Price: $38, Supplier: Cooperativa de Quesos 'Las Cabras'
# Product: Queso Cabrales, Price: $21, Supplier: Cooperativa de Quesos 'Las Cabras'
# Product: Escargots de Bourgogne, Price: $13.25, Supplier: Escargots Nouveaux
# Product: Chang, Price: $19, Supplier: Exotic Liquids
# Product: Aniseed Syrup, Price: $10, Supplier: Exotic Liquids
# Product: Mozzarella di Giovanni, Price: $34.8, Supplier: Formaggi Fortini s.r.l.
# Product: Gorgonzola Telino, Price: $12.5, Supplier: Formaggi Fortini s.r.l.
# Product: Mascarpone Fabioli, Price: $32, Supplier: Formaggi Fortini s.r.l.
# Product: Tarte au sucre, Price: $49.3, Supplier: Forêts d'érables
# Product: Sirop d'érable, Price: $28.5, Supplier: Forêts d'érables
# Product: Perth Pasties, Price: $32.8, Supplier: G'day, Mate
# Product: Filo Mix, Price: $7, Supplier: G'day, Mate
# Product: Manjimup Dried Apples, Price: $53, Supplier: G'day, Mate
# Product: Raclette Courdavault, Price: $55, Supplier: Gai pâturage
# Product: Camembert Pierrot, Price: $34, Supplier: Gai pâturage
# Product: Grandma's Boysenberry Spread, Price: $25, Supplier: Grandma Kelly's Homestead
# Product: Uncle Bob's Organic Dried Pears, Price: $30, Supplier: Grandma Kelly's Homestead
# Product: Northwoods Cranberry Sauce, Price: $40, Supplier: Grandma Kelly's Homestead
# Product: NuNuCa Nuß-Nougat-Creme, Price: $14, Supplier: Heli Süßwaren GmbH & Co. KG
# Product: Gumbär Gummibärchen, Price: $31.23, Supplier: Heli Süßwaren GmbH & Co. KG
# Product: Schoggi Schokolade, Price: $43.9, Supplier: Heli Süßwaren GmbH & Co. KG
# Product: Valkoinen suklaa, Price: $16.25, Supplier: Karkki Oy
# Product: Lakkalikööri, Price: $18, Supplier: Karkki Oy
# Product: Maxilaku, Price: $20, Supplier: Karkki Oy
# Product: Gula Malacca, Price: $19.45, Supplier: Leka Trading
# Product: Ipoh Coffee, Price: $46, Supplier: Leka Trading
# Product: Singaporean Hokkien Fried Mee, Price: $14, Supplier: Leka Trading
# Product: Spegesild, Price: $12, Supplier: Lyngbysild
# Product: Rogede sild, Price: $9.5, Supplier: Lyngbysild
# Product: Pâté chinois, Price: $24, Supplier: Ma Maison
# Product: Tourtière, Price: $7.45, Supplier: Ma Maison
# Product: Konbu, Price: $6, Supplier: Mayumi's
# Product: Tofu, Price: $23.25, Supplier: Mayumi's
# Product: Genen Shouyu, Price: $13, Supplier: Mayumi's
# Product: Boston Crab Meat, Price: $18.4, Supplier: New England Seafood Cannery
# Product: Jack's New England Clam Chowder, Price: $9.65, Supplier: New England Seafood Cannery
# Product: Louisiana Hot Spiced Okra, Price: $17, Supplier: New Orleans Cajun Delights
# Product: Chef Anton's Gumbo Mix, Price: $21.35, Supplier: New Orleans Cajun Delights
# Product: Louisiana Fiery Hot Pepper Sauce, Price: $21.05, Supplier: New Orleans Cajun Delights
# Product: Chef Anton's Cajun Seasoning, Price: $22, Supplier: New Orleans Cajun Delights
# Product: Nord-Ost Matjeshering, Price: $25.89, Supplier: Nord-Ost-Fisch Handelsgesellschaft mbH
# Product: Gudbrandsdalsost, Price: $36, Supplier: Norske Meierier
# Product: Flotemysost, Price: $21.5, Supplier: Norske Meierier
# Product: Geitost, Price: $2.5, Supplier: Norske Meierier
# Product: Gustaf's Knäckebröd, Price: $21, Supplier: PB Knäckebröd AB
# Product: Tunnbröd, Price: $9, Supplier: PB Knäckebröd AB
# Product: Ravioli Angelo, Price: $19.5, Supplier: Pasta Buttini s.r.l.
# Product: Gnocchi di nonna Alice, Price: $38, Supplier: Pasta Buttini s.r.l.
# Product: Alice Mutton, Price: $39, Supplier: Pavlova, Ltd.
# Product: Outback Lager, Price: $15, Supplier: Pavlova, Ltd.
# Product: Pavlova, Price: $17.45, Supplier: Pavlova, Ltd.
# Product: Carnarvon Tigers, Price: $62.5, Supplier: Pavlova, Ltd.
# Product: Vegie-spread, Price: $43.9, Supplier: Pavlova, Ltd.
# Product: Rhönbräu Klosterbier, Price: $7.75, Supplier: Plutzer Lebensmittelgroßmärkte AG
# Product: Wimmers gute Semmelknödel, Price: $33.25, Supplier: Plutzer Lebensmittelgroßmärkte AG
# Product: Original Frankfurter grüne Soße, Price: $13, Supplier: Plutzer Lebensmittelgroßmärkte AG
# Product: Thüringer Rostbratwurst, Price: $123.79, Supplier: Plutzer Lebensmittelgroßmärkte AG
# Product: Rössle Sauerkraut, Price: $45.6, Supplier: Plutzer Lebensmittelgroßmärkte AG
# Product: Guaraná Fantástica, Price: $4.5, Supplier: Refrescos Americanas LTDA
# Product: Chai, Price: $18, Supplier: Specialty Biscuits, Ltd.
# Product: Scottish Longbreads, Price: $12.5, Supplier: Specialty Biscuits, Ltd.
# Product: Sir Rodney's Scones, Price: $10, Supplier: Specialty Biscuits, Ltd.
# Product: Sir Rodney's Marmalade, Price: $81, Supplier: Specialty Biscuits, Ltd.
# Product: Teatime Chocolate Biscuits, Price: $9.2, Supplier: Specialty Biscuits, Ltd.
# Product: Gravad lax, Price: $26, Supplier: Svensk Sjöföda AB
# Product: Inlagd Sill, Price: $19, Supplier: Svensk Sjöföda AB
# Product: Röd Kaviar, Price: $15, Supplier: Svensk Sjöföda AB
# Product: Longlife Tofu, Price: $10, Supplier: Tokyo Traders
# Product: Mishi Kobe Niku, Price: $97, Supplier: Tokyo Traders
# Product: Ikura, Price: $31, Supplier: Tokyo Traders
# Product: Chocolade, Price: $12.75, Supplier: Zaanse Snoepfabriek
# Product: Zaanse koeken, Price: $9.5, Supplier: Zaanse Snoepfabriek

# %% [markdown]
# 1C) For each customer, list all the products they have purchased. The output should contain the customer information, along with a list of purchased products with product name, total quantity purchased, and total spent (computed from the list of products).
#
#
# This query required traversing multiple relationships: customers → orders → order details → products. I used a series of `$lookup` operations to join these collections together, followed by `$unwind` operators to flatten the nested arrays (orders and OrderDetails) so I could access individual items. The pipeline then groups by both customer and product using `$group`, calculating the total quantity purchased and total spent per product using `$sum` and `$multiply` aggregation operators. A second `$group` stage collects all products for each customer into a single array using `$push`. This demonstrates MongoDB's ability to handle complex multi-level joins and aggregations across both embedded documents (OrderDetails) and referenced collections (customers, products).

# %%
# This requires joining customers -> orders -> order details -> products
# We use multiple $lookup operations to traverse these relationships

pipeline = [
    {
        # Join customers with their orders
        "$lookup": {
            "from": "orders",
            "localField": "_id",
            "foreignField": "CustomerID",
            "as": "customer_orders"
        }
    },
    {
        # Only include customers who have placed orders
        "$match": {
            "customer_orders": { "$ne": [] }
        }
    },
    {
        # Flatten the orders array
        "$unwind": "$customer_orders"
    },
    {
        # Flatten the OrderDetails array within each order
        "$unwind": "$customer_orders.OrderDetails"
    },
    {
        # Join with products to get product names
        "$lookup": {
            "from": "products",
            "localField": "customer_orders.OrderDetails.ProductID",
            "foreignField": "_id",
            "as": "product_info"
        }
    },
    {
        # Flatten product info
        "$unwind": "$product_info"
    },
    {
        # Group by customer and product to calculate totals
        "$group": {
            "_id": {
                "CustomerID": "$_id",
                "CompanyName": "$CompanyName",
                "ProductID": "$customer_orders.OrderDetails.ProductID",
                "ProductName": "$product_info.ProductName"
            },
            "TotalQuantity": { 
                "$sum": "$customer_orders.OrderDetails.Quantity" 
            },
            "TotalSpent": { 
                "$sum": { 
                    "$multiply": [
                        "$customer_orders.OrderDetails.Quantity",
                        "$customer_orders.OrderDetails.UnitPrice"
                    ]
                }
            }
        }
    },
    {
        # Group again by customer to collect all their products
        "$group": {
            "_id": "$_id.CustomerID",
            "CompanyName": { "$first": "$_id.CompanyName" },
            "ProductsPurchased": {
                "$push": {
                    "ProductName": "$_id.ProductName",
                    "TotalQuantity": "$TotalQuantity",
                    "TotalSpent": "$TotalSpent"
                }
            }
        }
    },
    {
        # Sort by company name
        "$sort": { "CompanyName": 1 }
    }
]

result = customers.aggregate(pipeline)

# Print results
for customer in result:
    print(f"\nCustomer: {customer['CompanyName']}")
    print(f"Products purchased: {len(customer['ProductsPurchased'])}")
    for product in customer['ProductsPurchased']:
        print(f"  - {product['ProductName']}")
        print(f"    Total Quantity: {product['TotalQuantity']}")
        print(f"    Total Spent: ${product['TotalSpent']:.2f}")
# Out:
# Customer: Alfreds Futterkiste
# Products purchased: 11
#   - Vegie-spread
#     Total Quantity: 20
#     Total Spent: $878.00
#   - Aniseed Syrup
#     Total Quantity: 6
#     Total Spent: $60.00
#   - Grandma's Boysenberry Spread
#     Total Quantity: 16
#     Total Spent: $400.00
#   - Original Frankfurter grüne Soße
#     Total Quantity: 2
#     Total Spent: $26.00
#   - Raclette Courdavault
#     Total Quantity: 15
#     Total Spent: $825.00
#   - Escargots de Bourgogne
#     Total Quantity: 40
#     Total Spent: $530.00
#   - Lakkalikööri
#     Total Quantity: 15
#     Total Spent: $270.00
#   - Rössle Sauerkraut
#     Total Quantity: 17
#     Total Spent: $775.20
#   - Chartreuse verte
#     Total Quantity: 21
#     Total Spent: $378.00
#   - Spegesild
#     Total Quantity: 2
#     Total Spent: $24.00
#   - Flotemysost
#     Total Quantity: 20
#     Total Spent: $430.00
#
# Customer: Ana Trujillo Emparedados y helados
# Products purchased: 10
#   - Mascarpone Fabioli
#     Total Quantity: 10
#     Total Spent: $320.00
#   - Konbu
#     Total Quantity: 10
#     Total Spent: $60.00
#   - Teatime Chocolate Biscuits
#     Total Quantity: 7
#     Total Spent: $64.40
#   - Gudbrandsdalsost
#     Total Quantity: 1
#     Total Spent: $28.80
#   - Camembert Pierrot
#     Total Quantity: 10
#     Total Spent: $340.00
#   - Tofu
#     Total Quantity: 3
#     Total Spent: $69.75
#   - Queso Cabrales
#     Total Quantity: 2
#     Total Spent: $42.00
#   - Outback Lager
#     Total Quantity: 5
#     Total Spent: $60.00
#   - Mozzarella di Giovanni
#     Total Quantity: 10
#     Total Spent: $348.00
#   - Singaporean Hokkien Fried Mee
#     Total Quantity: 5
#     Total Spent: $70.00
#
# Customer: Antonio Moreno Taquería
# Products purchased: 15
#   - Geitost
#     Total Quantity: 38
#     Total Spent: $95.00
#   - Sasquatch Ale
#     Total Quantity: 40
#     Total Spent: $560.00
#   - Singaporean Hokkien Fried Mee
#     Total Quantity: 20
#     Total Spent: $280.00
#   - Ravioli Angelo
#     Total Quantity: 5
#     Total Spent: $97.50
#   - Queso Cabrales
#     Total Quantity: 74
#     Total Spent: $1453.20
#   - Raclette Courdavault
#     Total Quantity: 15
#     Total Spent: $825.00
#   - Boston Crab Meat
#     Total Quantity: 10
#     Total Spent: $184.00
#   - Louisiana Hot Spiced Okra
#     Total Quantity: 4
#     Total Spent: $68.00
#   - Chocolade
#     Total Quantity: 15
#     Total Spent: $191.25
#   - Chang
#     Total Quantity: 20
#     Total Spent: $380.00
#   - Perth Pasties
#     Total Quantity: 25
#     Total Spent: $820.00
#   - Ipoh Coffee
#     Total Quantity: 15
#     Total Spent: $690.00
#   - Rhönbräu Klosterbier
#     Total Quantity: 30
#     Total Spent: $232.50
#   - Gumbär Gummibärchen
#     Total Quantity: 30
#     Total Spent: $936.90
#   - Alice Mutton
#     Total Quantity: 18
#     Total Spent: $702.00
#
# Customer: Around the Horn
# Products purchased: 24
#   - Manjimup Dried Apples
#     Total Quantity: 20
#     Total Spent: $1060.00
#   - Chocolade
#     Total Quantity: 15
#     Total Spent: $153.00
#   - Outback Lager
#     Total Quantity: 53
#     Total Spent: $720.00
#   - Gustaf's Knäckebröd
#     Total Quantity: 4
#     Total Spent: $84.00
#   - Konbu
#     Total Quantity: 20
#     Total Spent: $96.00
#   - Gnocchi di nonna Alice
#     Total Quantity: 20
#     Total Spent: $608.00
#   - Perth Pasties
#     Total Quantity: 18
#     Total Spent: $590.40
#   - Röd Kaviar
#     Total Quantity: 3
#     Total Spent: $45.00
#   - Filo Mix
#     Total Quantity: 38
#     Total Spent: $266.00
#   - Jack's New England Clam Chowder
#     Total Quantity: 14
#     Total Spent: $135.10
#   - Pâté chinois
#     Total Quantity: 21
#     Total Spent: $504.00
#   - Gorgonzola Telino
#     Total Quantity: 115
#     Total Spent: $1437.50
#   - Flotemysost
#     Total Quantity: 12
#     Total Spent: $258.00
#   - Sir Rodney's Marmalade
#     Total Quantity: 50
#     Total Spent: $4050.00
#   - Valkoinen suklaa
#     Total Quantity: 39
#     Total Spent: $585.00
#   - Chang
#     Total Quantity: 15
#     Total Spent: $285.00
#   - Laughing Lumberjack Lager
#     Total Quantity: 15
#     Total Spent: $210.00
#   - Inlagd Sill
#     Total Quantity: 16
#     Total Spent: $304.00
#   - Spegesild
#     Total Quantity: 28
#     Total Spent: $336.00
#   - Steeleye Stout
#     Total Quantity: 4
#     Total Spent: $72.00
#   - Guaraná Fantástica
#     Total Quantity: 25
#     Total Spent: $90.00
#   - Camembert Pierrot
#     Total Quantity: 15
#     Total Spent: $510.00
#   - Zaanse koeken
#     Total Quantity: 25
#     Total Spent: $237.50
#   - Ravioli Angelo
#     Total Quantity: 65
#     Total Spent: $1170.00
#
# Customer: B's Beverages
# Products purchased: 19
#   - Wimmers gute Semmelknödel
#     Total Quantity: 9
#     Total Spent: $239.40
#   - Spegesild
#     Total Quantity: 15
#     Total Spent: $180.00
#   - Manjimup Dried Apples
#     Total Quantity: 3
#     Total Spent: $127.20
#   - Ravioli Angelo
#     Total Quantity: 6
#     Total Spent: $117.00
#   - Outback Lager
#     Total Quantity: 7
#     Total Spent: $105.00
#   - Gustaf's Knäckebröd
#     Total Quantity: 21
#     Total Spent: $441.00
#   - Gnocchi di nonna Alice
#     Total Quantity: 20
#     Total Spent: $608.00
#   - Geitost
#     Total Quantity: 15
#     Total Spent: $37.50
#   - Mozzarella di Giovanni
#     Total Quantity: 1
#     Total Spent: $34.80
#   - Aniseed Syrup
#     Total Quantity: 30
#     Total Spent: $240.00
#   - Boston Crab Meat
#     Total Quantity: 10
#     Total Spent: $147.00
#   - Uncle Bob's Organic Dried Pears
#     Total Quantity: 34
#     Total Spent: $840.00
#   - Tarte au sucre
#     Total Quantity: 10
#     Total Spent: $493.00
#   - Maxilaku
#     Total Quantity: 6
#     Total Spent: $120.00
#   - Sir Rodney's Scones
#     Total Quantity: 29
#     Total Spent: $262.00
#   - Raclette Courdavault
#     Total Quantity: 4
#     Total Spent: $220.00
#   - Steeleye Stout
#     Total Quantity: 20
#     Total Spent: $360.00
#   - Konbu
#     Total Quantity: 23
#     Total Spent: $138.00
#   - Ipoh Coffee
#     Total Quantity: 30
#     Total Spent: $1380.00
#
# Customer: Berglunds snabbköp
# Products purchased: 37
#   - Flotemysost
#     Total Quantity: 32
#     Total Spent: $688.00
#   - Tofu
#     Total Quantity: 16
#     Total Spent: $372.00
#   - Guaraná Fantástica
#     Total Quantity: 18
#     Total Spent: $70.20
#   - Rössle Sauerkraut
#     Total Quantity: 50
#     Total Spent: $2280.00
#   - Camembert Pierrot
#     Total Quantity: 35
#     Total Spent: $1088.00
#   - Konbu
#     Total Quantity: 6
#     Total Spent: $36.00
#   - Sir Rodney's Marmalade
#     Total Quantity: 28
#     Total Spent: $1814.40
#   - Pavlova
#     Total Quantity: 12
#     Total Spent: $209.40
#   - Pâté chinois
#     Total Quantity: 20
#     Total Spent: $384.00
#   - Ipoh Coffee
#     Total Quantity: 60
#     Total Spent: $2760.00
#   - Raclette Courdavault
#     Total Quantity: 15
#     Total Spent: $660.00
#   - Alice Mutton
#     Total Quantity: 10
#     Total Spent: $312.00
#   - Mascarpone Fabioli
#     Total Quantity: 10
#     Total Spent: $320.00
#   - Teatime Chocolate Biscuits
#     Total Quantity: 25
#     Total Spent: $230.00
#   - Filo Mix
#     Total Quantity: 25
#     Total Spent: $175.00
#   - Vegie-spread
#     Total Quantity: 8
#     Total Spent: $280.80
#   - Aniseed Syrup
#     Total Quantity: 30
#     Total Spent: $300.00
#   - Côte de Blaye
#     Total Quantity: 15
#     Total Spent: $3952.50
#   - Rhönbräu Klosterbier
#     Total Quantity: 51
#     Total Spent: $348.75
#   - Gumbär Gummibärchen
#     Total Quantity: 50
#     Total Spent: $1466.55
#   - Jack's New England Clam Chowder
#     Total Quantity: 40
#     Total Spent: $327.50
#   - Perth Pasties
#     Total Quantity: 12
#     Total Spent: $393.60
#   - Chef Anton's Cajun Seasoning
#     Total Quantity: 12
#     Total Spent: $264.00
#   - Röd Kaviar
#     Total Quantity: 25
#     Total Spent: $300.00
#   - Steeleye Stout
#     Total Quantity: 8
#     Total Spent: $115.20
#   - Thüringer Rostbratwurst
#     Total Quantity: 10
#     Total Spent: $1237.90
#   - Nord-Ost Matjeshering
#     Total Quantity: 50
#     Total Spent: $1294.50
#   - Gula Malacca
#     Total Quantity: 16
#     Total Spent: $248.00
#   - Maxilaku
#     Total Quantity: 15
#     Total Spent: $300.00
#   - Boston Crab Meat
#     Total Quantity: 75
#     Total Spent: $1380.00
#   - Chai
#     Total Quantity: 35
#     Total Spent: $630.00
#   - Chang
#     Total Quantity: 21
#     Total Spent: $399.00
#   - Tourtière
#     Total Quantity: 36
#     Total Spent: $244.95
#   - Lakkalikööri
#     Total Quantity: 21
#     Total Spent: $378.00
#   - Zaanse koeken
#     Total Quantity: 61
#     Total Spent: $579.50
#   - Chartreuse verte
#     Total Quantity: 26
#     Total Spent: $446.40
#   - Ikura
#     Total Quantity: 22
#     Total Spent: $682.00
#
# Customer: Blauer See Delikatessen
# Products purchased: 12
#   - Queso Cabrales
#     Total Quantity: 14
#     Total Spent: $294.00
#   - Tourtière
#     Total Quantity: 20
#     Total Spent: $149.00
#   - Carnarvon Tigers
#     Total Quantity: 10
#     Total Spent: $625.00
#   - Rössle Sauerkraut
#     Total Quantity: 3
#     Total Spent: $136.80
#   - Lakkalikööri
#     Total Quantity: 14
#     Total Spent: $252.00
#   - Sirop d'érable
#     Total Quantity: 4
#     Total Spent: $114.00
#   - Zaanse koeken
#     Total Quantity: 14
#     Total Spent: $133.00
#   - Ravioli Angelo
#     Total Quantity: 4
#     Total Spent: $78.00
#   - Chartreuse verte
#     Total Quantity: 5
#     Total Spent: $90.00
#   - Camembert Pierrot
#     Total Quantity: 21
#     Total Spent: $714.00
#   - Sir Rodney's Scones
#     Total Quantity: 23
#     Total Spent: $230.00
#   - Manjimup Dried Apples
#     Total Quantity: 8
#     Total Spent: $424.00
#
# Customer: Blondesddsl père et fils
# Products purchased: 25
#   - Thüringer Rostbratwurst
#     Total Quantity: 35
#     Total Spent: $3465.00
#   - Ikura
#     Total Quantity: 14
#     Total Spent: $347.20
#   - Outback Lager
#     Total Quantity: 20
#     Total Spent: $240.00
#   - Gorgonzola Telino
#     Total Quantity: 85
#     Total Spent: $1062.50
#   - Rhönbräu Klosterbier
#     Total Quantity: 24
#     Total Spent: $148.80
#   - Queso Cabrales
#     Total Quantity: 35
#     Total Spent: $735.00
#   - Jack's New England Clam Chowder
#     Total Quantity: 12
#     Total Spent: $115.80
#   - Maxilaku
#     Total Quantity: 35
#     Total Spent: $560.00
#   - Chai
#     Total Quantity: 25
#     Total Spent: $450.00
#   - Tarte au sucre
#     Total Quantity: 35
#     Total Spent: $1379.00
#   - Wimmers gute Semmelknödel
#     Total Quantity: 30
#     Total Spent: $798.00
#   - Pâté chinois
#     Total Quantity: 18
#     Total Spent: $432.00
#   - Gnocchi di nonna Alice
#     Total Quantity: 40
#     Total Spent: $1216.00
#   - Lakkalikööri
#     Total Quantity: 10
#     Total Spent: $180.00
#   - Chartreuse verte
#     Total Quantity: 60
#     Total Spent: $864.00
#   - Rössle Sauerkraut
#     Total Quantity: 30
#     Total Spent: $1092.00
#   - Raclette Courdavault
#     Total Quantity: 12
#     Total Spent: $660.00
#   - Ravioli Angelo
#     Total Quantity: 15
#     Total Spent: $292.50
#   - Mozzarella di Giovanni
#     Total Quantity: 20
#     Total Spent: $556.00
#   - Spegesild
#     Total Quantity: 5
#     Total Spent: $48.00
#   - Côte de Blaye
#     Total Quantity: 10
#     Total Spent: $2108.00
#   - Filo Mix
#     Total Quantity: 20
#     Total Spent: $112.00
#   - Tourtière
#     Total Quantity: 28
#     Total Spent: $165.20
#   - Carnarvon Tigers
#     Total Quantity: 18
#     Total Spent: $1125.00
#   - Alice Mutton
#     Total Quantity: 30
#     Total Spent: $936.00
#
# Customer: Bon app'
# Products purchased: 34
#   - Gorgonzola Telino
#     Total Quantity: 3
#     Total Spent: $37.50
#   - Manjimup Dried Apples
#     Total Quantity: 40
#     Total Spent: $1908.00
#   - Tofu
#     Total Quantity: 20
#     Total Spent: $465.00
#   - Teatime Chocolate Biscuits
#     Total Quantity: 10
#     Total Spent: $92.00
#   - Rhönbräu Klosterbier
#     Total Quantity: 20
#     Total Spent: $155.00
#   - Flotemysost
#     Total Quantity: 30
#     Total Spent: $645.00
#   - Pavlova
#     Total Quantity: 57
#     Total Spent: $994.65
#   - Zaanse koeken
#     Total Quantity: 30
#     Total Spent: $285.00
#   - Inlagd Sill
#     Total Quantity: 30
#     Total Spent: $570.00
#   - Konbu
#     Total Quantity: 20
#     Total Spent: $120.00
#   - Uncle Bob's Organic Dried Pears
#     Total Quantity: 58
#     Total Spent: $1740.00
#   - Mozzarella di Giovanni
#     Total Quantity: 16
#     Total Spent: $556.80
#   - Lakkalikööri
#     Total Quantity: 20
#     Total Spent: $360.00
#   - Tarte au sucre
#     Total Quantity: 14
#     Total Spent: $690.20
#   - Gudbrandsdalsost
#     Total Quantity: 25
#     Total Spent: $900.00
#   - Carnarvon Tigers
#     Total Quantity: 50
#     Total Spent: $2500.00
#   - Boston Crab Meat
#     Total Quantity: 45
#     Total Spent: $828.00
#   - Tourtière
#     Total Quantity: 39
#     Total Spent: $230.10
#   - Tunnbröd
#     Total Quantity: 15
#     Total Spent: $108.00
#   - Louisiana Fiery Hot Pepper Sauce
#     Total Quantity: 10
#     Total Spent: $210.50
#   - Singaporean Hokkien Fried Mee
#     Total Quantity: 30
#     Total Spent: $420.00
#   - Ipoh Coffee
#     Total Quantity: 40
#     Total Spent: $1472.00
#   - Jack's New England Clam Chowder
#     Total Quantity: 12
#     Total Spent: $92.40
#   - Alice Mutton
#     Total Quantity: 16
#     Total Spent: $624.00
#   - Ikura
#     Total Quantity: 36
#     Total Spent: $1116.00
#   - Chartreuse verte
#     Total Quantity: 21
#     Total Spent: $378.00
#   - Spegesild
#     Total Quantity: 21
#     Total Spent: $252.00
#   - Northwoods Cranberry Sauce
#     Total Quantity: 10
#     Total Spent: $400.00
#   - Ravioli Angelo
#     Total Quantity: 14
#     Total Spent: $273.00
#   - Gnocchi di nonna Alice
#     Total Quantity: 30
#     Total Spent: $1140.00
#   - NuNuCa Nuß-Nougat-Creme
#     Total Quantity: 50
#     Total Spent: $560.00
#   - Chef Anton's Cajun Seasoning
#     Total Quantity: 50
#     Total Spent: $1100.00
#   - Grandma's Boysenberry Spread
#     Total Quantity: 70
#     Total Spent: $1750.00
#   - Wimmers gute Semmelknödel
#     Total Quantity: 28
#     Total Spent: $877.80
#
# Customer: Bottom-Dollar Markets
# Products purchased: 27
#   - Scottish Longbreads
#     Total Quantity: 42
#     Total Spent: $525.00
#   - Northwoods Cranberry Sauce
#     Total Quantity: 16
#     Total Spent: $640.00
#   - Jack's New England Clam Chowder
#     Total Quantity: 25
#     Total Spent: $192.50
#   - Raclette Courdavault
#     Total Quantity: 25
#     Total Spent: $1100.00
#   - Rhönbräu Klosterbier
#     Total Quantity: 10
#     Total Spent: $77.50
#   - Gula Malacca
#     Total Quantity: 58
#     Total Spent: $970.10
#   - Mozzarella di Giovanni
#     Total Quantity: 35
#     Total Spent: $1218.00
#   - Boston Crab Meat
#     Total Quantity: 50
#     Total Spent: $735.00
#   - Ikura
#     Total Quantity: 46
#     Total Spent: $1326.80
#   - Alice Mutton
#     Total Quantity: 56
#     Total Spent: $1794.00
#   - Singaporean Hokkien Fried Mee
#     Total Quantity: 20
#     Total Spent: $224.00
#   - Geitost
#     Total Quantity: 64
#     Total Spent: $135.50
#   - Chai
#     Total Quantity: 60
#     Total Spent: $1080.00
#   - Aniseed Syrup
#     Total Quantity: 20
#     Total Spent: $200.00
#   - Manjimup Dried Apples
#     Total Quantity: 24
#     Total Spent: $1272.00
#   - Tarte au sucre
#     Total Quantity: 101
#     Total Spent: $4781.30
#   - Gnocchi di nonna Alice
#     Total Quantity: 18
#     Total Spent: $684.00
#   - Camembert Pierrot
#     Total Quantity: 75
#     Total Spent: $2550.00
#   - Grandma's Boysenberry Spread
#     Total Quantity: 12
#     Total Spent: $300.00
#   - Zaanse koeken
#     Total Quantity: 30
#     Total Spent: $228.00
#   - Pâté chinois
#     Total Quantity: 15
#     Total Spent: $288.00
#   - Outback Lager
#     Total Quantity: 30
#     Total Spent: $360.00
#   - Guaraná Fantástica
#     Total Quantity: 30
#     Total Spent: $135.00
#   - Uncle Bob's Organic Dried Pears
#     Total Quantity: 20
#     Total Spent: $600.00
#   - Queso Cabrales
#     Total Quantity: 5
#     Total Spent: $105.00
#   - NuNuCa Nuß-Nougat-Creme
#     Total Quantity: 60
#     Total Spent: $672.00
#   - Ipoh Coffee
#     Total Quantity: 9
#     Total Spent: $414.00
#
# Customer: Bólido Comidas preparadas
# Products purchased: 6
#   - Chef Anton's Cajun Seasoning
#     Total Quantity: 24
#     Total Spent: $422.40
#   - Filo Mix
#     Total Quantity: 40
#     Total Spent: $280.00
#   - Thüringer Rostbratwurst
#     Total Quantity: 20
#     Total Spent: $2475.80
#   - Alice Mutton
#     Total Quantity: 40
#     Total Spent: $1560.00
#   - Rhönbräu Klosterbier
#     Total Quantity: 50
#     Total Spent: $310.00
#   - Ravioli Angelo
#     Total Quantity: 16
#     Total Spent: $249.60
#
# Customer: Cactus Comidas para llevar
# Products purchased: 11
#   - Steeleye Stout
#     Total Quantity: 3
#     Total Spent: $54.00
#   - Geitost
#     Total Quantity: 10
#     Total Spent: $25.00
#   - Sasquatch Ale
#     Total Quantity: 20
#     Total Spent: $280.00
#   - Laughing Lumberjack Lager
#     Total Quantity: 20
#     Total Spent: $280.00
#   - Jack's New England Clam Chowder
#     Total Quantity: 10
#     Total Spent: $96.50
#   - Röd Kaviar
#     Total Quantity: 10
#     Total Spent: $150.00
#   - Rössle Sauerkraut
#     Total Quantity: 8
#     Total Spent: $364.80
#   - Ipoh Coffee
#     Total Quantity: 7
#     Total Spent: $322.00
#   - Scottish Longbreads
#     Total Quantity: 6
#     Total Spent: $75.00
#   - Rhönbräu Klosterbier
#     Total Quantity: 20
#     Total Spent: $155.00
#   - Gorgonzola Telino
#     Total Quantity: 1
#     Total Spent: $12.50
#
# Customer: Centro comercial Moctezuma
# Products purchased: 2
#   - Gravad lax
#     Total Quantity: 1
#     Total Spent: $20.80
#   - Sir Rodney's Scones
#     Total Quantity: 10
#     Total Spent: $80.00
#
# Customer: Chop-suey Chinese
# Products purchased: 17
#   - Guaraná Fantástica
#     Total Quantity: 15
#     Total Spent: $54.00
#   - Ikura
#     Total Quantity: 16
#     Total Spent: $496.00
#   - Gudbrandsdalsost
#     Total Quantity: 40
#     Total Spent: $1440.00
#   - Manjimup Dried Apples
#     Total Quantity: 30
#     Total Spent: $1590.00
#   - Gravad lax
#     Total Quantity: 8
#     Total Spent: $208.00
#   - Sir Rodney's Scones
#     Total Quantity: 40
#     Total Spent: $400.00
#   - Konbu
#     Total Quantity: 6
#     Total Spent: $36.00
#   - Camembert Pierrot
#     Total Quantity: 10
#     Total Spent: $340.00
#   - Singaporean Hokkien Fried Mee
#     Total Quantity: 28
#     Total Spent: $392.00
#   - Wimmers gute Semmelknödel
#     Total Quantity: 30
#     Total Spent: $798.00
#   - Pâté chinois
#     Total Quantity: 21
#     Total Spent: $403.20
#   - Chang
#     Total Quantity: 30
#     Total Spent: $570.00
#   - Vegie-spread
#     Total Quantity: 42
#     Total Spent: $1843.80
#   - Gnocchi di nonna Alice
#     Total Quantity: 72
#     Total Spent: $2736.00
#   - Longlife Tofu
#     Total Quantity: 41
#     Total Spent: $328.00
#   - Chai
#     Total Quantity: 15
#     Total Spent: $216.00
#   - Tarte au sucre
#     Total Quantity: 21
#     Total Spent: $1035.30
#
# Customer: Comércio Mineiro
# Products purchased: 9
#   - Sirop d'érable
#     Total Quantity: 4
#     Total Spent: $114.00
#   - Queso Cabrales
#     Total Quantity: 10
#     Total Spent: $168.00
#   - Chef Anton's Gumbo Mix
#     Total Quantity: 20
#     Total Spent: $340.00
#   - Gula Malacca
#     Total Quantity: 15
#     Total Spent: $291.75
#   - Maxilaku
#     Total Quantity: 15
#     Total Spent: $240.00
#   - Original Frankfurter grüne Soße
#     Total Quantity: 10
#     Total Spent: $104.00
#   - Gnocchi di nonna Alice
#     Total Quantity: 30
#     Total Spent: $912.00
#   - Thüringer Rostbratwurst
#     Total Quantity: 15
#     Total Spent: $1485.00
#   - Spegesild
#     Total Quantity: 14
#     Total Spent: $156.00
#
# Customer: Consolidated Holdings
# Products purchased: 7
#   - Chef Anton's Gumbo Mix
#     Total Quantity: 30
#     Total Spent: $640.50
#   - Mozzarella di Giovanni
#     Total Quantity: 10
#     Total Spent: $278.00
#   - Konbu
#     Total Quantity: 1
#     Total Spent: $4.80
#   - Gustaf's Knäckebröd
#     Total Quantity: 12
#     Total Spent: $201.60
#   - Mishi Kobe Niku
#     Total Quantity: 3
#     Total Spent: $291.00
#   - Chang
#     Total Quantity: 10
#     Total Spent: $152.00
#   - Tunnbröd
#     Total Quantity: 21
#     Total Spent: $151.20
#
# Customer: Die Wandernde Kuh
# Products purchased: 22
#   - Rössle Sauerkraut
#     Total Quantity: 4
#     Total Spent: $145.60
#   - Chai
#     Total Quantity: 15
#     Total Spent: $216.00
#   - Sir Rodney's Scones
#     Total Quantity: 40
#     Total Spent: $400.00
#   - Mascarpone Fabioli
#     Total Quantity: 65
#     Total Spent: $2080.00
#   - Gorgonzola Telino
#     Total Quantity: 38
#     Total Spent: $400.00
#   - Boston Crab Meat
#     Total Quantity: 10
#     Total Spent: $147.00
#   - Geitost
#     Total Quantity: 20
#     Total Spent: $50.00
#   - Queso Manchego La Pastora
#     Total Quantity: 20
#     Total Spent: $760.00
#   - Gnocchi di nonna Alice
#     Total Quantity: 20
#     Total Spent: $608.00
#   - Teatime Chocolate Biscuits
#     Total Quantity: 12
#     Total Spent: $110.40
#   - Sirop d'érable
#     Total Quantity: 15
#     Total Spent: $427.50
#   - Steeleye Stout
#     Total Quantity: 18
#     Total Spent: $324.00
#   - Gustaf's Knäckebröd
#     Total Quantity: 20
#     Total Spent: $420.00
#   - Ipoh Coffee
#     Total Quantity: 24
#     Total Spent: $883.20
#   - Gudbrandsdalsost
#     Total Quantity: 40
#     Total Spent: $1296.00
#   - Perth Pasties
#     Total Quantity: 20
#     Total Spent: $524.00
#   - Tunnbröd
#     Total Quantity: 25
#     Total Spent: $180.00
#   - Pâté chinois
#     Total Quantity: 16
#     Total Spent: $326.40
#   - Rhönbräu Klosterbier
#     Total Quantity: 10
#     Total Spent: $62.00
#   - Outback Lager
#     Total Quantity: 15
#     Total Spent: $225.00
#   - Wimmers gute Semmelknödel
#     Total Quantity: 15
#     Total Spent: $498.75
#   - Chang
#     Total Quantity: 30
#     Total Spent: $570.00
#
# Customer: Drachenblut Delikatessen
# Products purchased: 9
#   - Lakkalikööri
#     Total Quantity: 12
#     Total Spent: $172.80
#   - Gumbär Gummibärchen
#     Total Quantity: 12
#     Total Spent: $374.76
#   - Jack's New England Clam Chowder
#     Total Quantity: 9
#     Total Spent: $86.85
#   - Queso Cabrales
#     Total Quantity: 20
#     Total Spent: $420.00
#   - Gorgonzola Telino
#     Total Quantity: 20
#     Total Spent: $200.00
#   - Raclette Courdavault
#     Total Quantity: 30
#     Total Spent: $1650.00
#   - Konbu
#     Total Quantity: 25
#     Total Spent: $128.40
#   - Rhönbräu Klosterbier
#     Total Quantity: 12
#     Total Spent: $74.40
#   - Perth Pasties
#     Total Quantity: 20
#     Total Spent: $656.00
#
# Customer: Du monde entier
# Products purchased: 9
#   - Alice Mutton
#     Total Quantity: 15
#     Total Spent: $585.00
#   - Chai
#     Total Quantity: 3
#     Total Spent: $54.00
#   - Singaporean Hokkien Fried Mee
#     Total Quantity: 6
#     Total Spent: $67.20
#   - Sasquatch Ale
#     Total Quantity: 10
#     Total Spent: $140.00
#   - Sir Rodney's Scones
#     Total Quantity: 6
#     Total Spent: $60.00
#   - Ikura
#     Total Quantity: 10
#     Total Spent: $310.00
#   - Jack's New England Clam Chowder
#     Total Quantity: 14
#     Total Spent: $135.10
#   - Gudbrandsdalsost
#     Total Quantity: 7
#     Total Spent: $201.60
#   - Filo Mix
#     Total Quantity: 9
#     Total Spent: $63.00
#
# Customer: Eastern Connection
# Products purchased: 19
#   - Louisiana Hot Spiced Okra
#     Total Quantity: 24
#     Total Spent: $408.00
#   - Uncle Bob's Organic Dried Pears
#     Total Quantity: 100
#     Total Spent: $3000.00
#   - Camembert Pierrot
#     Total Quantity: 50
#     Total Spent: $1700.00
#   - Ipoh Coffee
#     Total Quantity: 6
#     Total Spent: $276.00
#   - Geitost
#     Total Quantity: 30
#     Total Spent: $75.00
#   - Nord-Ost Matjeshering
#     Total Quantity: 15
#     Total Spent: $388.35
#   - Thüringer Rostbratwurst
#     Total Quantity: 21
#     Total Spent: $2079.00
#   - Mozzarella di Giovanni
#     Total Quantity: 20
#     Total Spent: $696.00
#   - Flotemysost
#     Total Quantity: 55
#     Total Spent: $1161.00
#   - Louisiana Fiery Hot Pepper Sauce
#     Total Quantity: 21
#     Total Spent: $442.05
#   - Maxilaku
#     Total Quantity: 30
#     Total Spent: $480.00
#   - Chai
#     Total Quantity: 25
#     Total Spent: $450.00
#   - Queso Cabrales
#     Total Quantity: 5
#     Total Spent: $105.00
#   - Chef Anton's Gumbo Mix
#     Total Quantity: 30
#     Total Spent: $640.50
#   - Steeleye Stout
#     Total Quantity: 35
#     Total Spent: $504.00
#   - Gudbrandsdalsost
#     Total Quantity: 30
#     Total Spent: $864.00
#   - Pâté chinois
#     Total Quantity: 35
#     Total Spent: $840.00
#   - Gumbär Gummibärchen
#     Total Quantity: 12
#     Total Spent: $374.76
#   - Chef Anton's Cajun Seasoning
#     Total Quantity: 25
#     Total Spent: $550.00
#
# Customer: Ernst Handel
# Products purchased: 56
#   - Pavlova
#     Total Quantity: 146
#     Total Spent: $2260.15
#   - Louisiana Fiery Hot Pepper Sauce
#     Total Quantity: 114
#     Total Spent: $2357.20
#   - Wimmers gute Semmelknödel
#     Total Quantity: 199
#     Total Spent: $6384.00
#   - Singaporean Hokkien Fried Mee
#     Total Quantity: 40
#     Total Spent: $560.00
#   - Konbu
#     Total Quantity: 78
#     Total Spent: $468.00
#   - Longlife Tofu
#     Total Quantity: 86
#     Total Spent: $688.00
#   - Gnocchi di nonna Alice
#     Total Quantity: 100
#     Total Spent: $3572.00
#   - Spegesild
#     Total Quantity: 45
#     Total Spent: $432.00
#   - Alice Mutton
#     Total Quantity: 121
#     Total Spent: $4368.00
#   - Mascarpone Fabioli
#     Total Quantity: 6
#     Total Spent: $153.60
#   - Ikura
#     Total Quantity: 100
#     Total Spent: $3100.00
#   - Gorgonzola Telino
#     Total Quantity: 170
#     Total Spent: $1975.00
#   - Steeleye Stout
#     Total Quantity: 76
#     Total Spent: $1224.00
#   - Gustaf's Knäckebröd
#     Total Quantity: 52
#     Total Spent: $1092.00
#   - Sir Rodney's Scones
#     Total Quantity: 120
#     Total Spent: $1090.00
#   - Nord-Ost Matjeshering
#     Total Quantity: 60
#     Total Spent: $1242.00
#   - Gudbrandsdalsost
#     Total Quantity: 110
#     Total Spent: $3960.00
#   - Queso Cabrales
#     Total Quantity: 45
#     Total Spent: $819.00
#   - Chang
#     Total Quantity: 58
#     Total Spent: $912.00
#   - Carnarvon Tigers
#     Total Quantity: 9
#     Total Spent: $450.00
#   - Ravioli Angelo
#     Total Quantity: 49
#     Total Spent: $858.00
#   - Vegie-spread
#     Total Quantity: 100
#     Total Spent: $3818.00
#   - Sirop d'érable
#     Total Quantity: 186
#     Total Spent: $5301.00
#   - Chartreuse verte
#     Total Quantity: 175
#     Total Spent: $3150.00
#   - Thüringer Rostbratwurst
#     Total Quantity: 26
#     Total Spent: $2871.48
#   - Aniseed Syrup
#     Total Quantity: 45
#     Total Spent: $450.00
#   - Chef Anton's Gumbo Mix
#     Total Quantity: 97
#     Total Spent: $1649.00
#   - Outback Lager
#     Total Quantity: 38
#     Total Spent: $570.00
#   - Sasquatch Ale
#     Total Quantity: 150
#     Total Spent: $2100.00
#   - Geitost
#     Total Quantity: 60
#     Total Spent: $120.00
#   - Gumbär Gummibärchen
#     Total Quantity: 35
#     Total Spent: $1093.05
#   - Guaraná Fantástica
#     Total Quantity: 248
#     Total Spent: $1090.80
#   - Rössle Sauerkraut
#     Total Quantity: 118
#     Total Spent: $5261.20
#   - Tarte au sucre
#     Total Quantity: 80
#     Total Spent: $3944.00
#   - Rogede sild
#     Total Quantity: 27
#     Total Spent: $256.50
#   - Camembert Pierrot
#     Total Quantity: 160
#     Total Spent: $5440.00
#   - Tourtière
#     Total Quantity: 80
#     Total Spent: $472.00
#   - Queso Manchego La Pastora
#     Total Quantity: 86
#     Total Spent: $3268.00
#   - Manjimup Dried Apples
#     Total Quantity: 120
#     Total Spent: $6360.00
#   - Raclette Courdavault
#     Total Quantity: 180
#     Total Spent: $9130.00
#   - Flotemysost
#     Total Quantity: 51
#     Total Spent: $1096.50
#   - Rhönbräu Klosterbier
#     Total Quantity: 57
#     Total Spent: $441.75
#   - Côte de Blaye
#     Total Quantity: 20
#     Total Spent: $4216.00
#   - Valkoinen suklaa
#     Total Quantity: 22
#     Total Spent: $357.50
#   - Sir Rodney's Marmalade
#     Total Quantity: 39
#     Total Spent: $3159.00
#   - Louisiana Hot Spiced Okra
#     Total Quantity: 60
#     Total Spent: $816.00
#   - Mozzarella di Giovanni
#     Total Quantity: 24
#     Total Spent: $667.20
#   - Uncle Bob's Organic Dried Pears
#     Total Quantity: 18
#     Total Spent: $540.00
#   - Tunnbröd
#     Total Quantity: 60
#     Total Spent: $432.00
#   - Pâté chinois
#     Total Quantity: 65
#     Total Spent: $1560.00
#   - Boston Crab Meat
#     Total Quantity: 91
#     Total Spent: $1674.40
#   - Schoggi Schokolade
#     Total Quantity: 30
#     Total Spent: $1317.00
#   - Tofu
#     Total Quantity: 11
#     Total Spent: $255.75
#   - Gula Malacca
#     Total Quantity: 77
#     Total Spent: $1193.50
#   - Jack's New England Clam Chowder
#     Total Quantity: 53
#     Total Spent: $486.10
#   - Chocolade
#     Total Quantity: 70
#     Total Spent: $714.00
#
# Customer: Familia Arquibaldo
# Products purchased: 17
#   - Rhönbräu Klosterbier
#     Total Quantity: 56
#     Total Spent: $424.70
#   - Tourtière
#     Total Quantity: 30
#     Total Spent: $223.50
#   - Zaanse koeken
#     Total Quantity: 6
#     Total Spent: $57.00
#   - Pâté chinois
#     Total Quantity: 6
#     Total Spent: $144.00
#   - Teatime Chocolate Biscuits
#     Total Quantity: 18
#     Total Spent: $131.40
#   - Chartreuse verte
#     Total Quantity: 50
#     Total Spent: $720.00
#   - Jack's New England Clam Chowder
#     Total Quantity: 12
#     Total Spent: $115.80
#   - Nord-Ost Matjeshering
#     Total Quantity: 30
#     Total Spent: $776.70
#   - Perth Pasties
#     Total Quantity: 25
#     Total Spent: $820.00
#   - Sasquatch Ale
#     Total Quantity: 10
#     Total Spent: $112.00
#   - Guaraná Fantástica
#     Total Quantity: 25
#     Total Spent: $99.00
#   - NuNuCa Nuß-Nougat-Creme
#     Total Quantity: 10
#     Total Spent: $112.00
#   - Boston Crab Meat
#     Total Quantity: 4
#     Total Spent: $58.80
#   - Filo Mix
#     Total Quantity: 4
#     Total Spent: $28.00
#   - Geitost
#     Total Quantity: 50
#     Total Spent: $100.00
#   - Spegesild
#     Total Quantity: 9
#     Total Spent: $108.00
#   - Camembert Pierrot
#     Total Quantity: 12
#     Total Spent: $408.00
#
# Customer: Folies gourmandes
# Products purchased: 15
#   - Rhönbräu Klosterbier
#     Total Quantity: 2
#     Total Spent: $15.50
#   - Carnarvon Tigers
#     Total Quantity: 80
#     Total Spent: $5000.00
#   - Manjimup Dried Apples
#     Total Quantity: 15
#     Total Spent: $795.00
#   - Scottish Longbreads
#     Total Quantity: 18
#     Total Spent: $225.00
#   - Raclette Courdavault
#     Total Quantity: 12
#     Total Spent: $528.00
#   - Tarte au sucre
#     Total Quantity: 35
#     Total Spent: $1379.00
#   - Uncle Bob's Organic Dried Pears
#     Total Quantity: 35
#     Total Spent: $1050.00
#   - Sir Rodney's Scones
#     Total Quantity: 40
#     Total Spent: $400.00
#   - Guaraná Fantástica
#     Total Quantity: 20
#     Total Spent: $90.00
#   - Gravad lax
#     Total Quantity: 10
#     Total Spent: $208.00
#   - Gustaf's Knäckebröd
#     Total Quantity: 6
#     Total Spent: $126.00
#   - Vegie-spread
#     Total Quantity: 30
#     Total Spent: $1317.00
#   - Zaanse koeken
#     Total Quantity: 30
#     Total Spent: $228.00
#   - Steeleye Stout
#     Total Quantity: 15
#     Total Spent: $270.00
#   - Tourtière
#     Total Quantity: 6
#     Total Spent: $35.40
#
# Customer: Folk och fä HB
# Products purchased: 30
#   - Zaanse koeken
#     Total Quantity: 60
#     Total Spent: $570.00
#   - Manjimup Dried Apples
#     Total Quantity: 88
#     Total Spent: $4664.00
#   - Flotemysost
#     Total Quantity: 6
#     Total Spent: $103.20
#   - Vegie-spread
#     Total Quantity: 20
#     Total Spent: $878.00
#   - Chang
#     Total Quantity: 65
#     Total Spent: $1007.00
#   - Spegesild
#     Total Quantity: 25
#     Total Spent: $300.00
#   - Outback Lager
#     Total Quantity: 59
#     Total Spent: $885.00
#   - Gorgonzola Telino
#     Total Quantity: 2
#     Total Spent: $25.00
#   - Mozzarella di Giovanni
#     Total Quantity: 24
#     Total Spent: $835.20
#   - Raclette Courdavault
#     Total Quantity: 35
#     Total Spent: $1925.00
#   - Gustaf's Knäckebröd
#     Total Quantity: 25
#     Total Spent: $525.00
#   - Rhönbräu Klosterbier
#     Total Quantity: 56
#     Total Spent: $427.80
#   - Queso Cabrales
#     Total Quantity: 56
#     Total Spent: $940.80
#   - Gnocchi di nonna Alice
#     Total Quantity: 60
#     Total Spent: $2280.00
#   - Nord-Ost Matjeshering
#     Total Quantity: 35
#     Total Spent: $724.50
#   - Tarte au sucre
#     Total Quantity: 6
#     Total Spent: $295.80
#   - Louisiana Hot Spiced Okra
#     Total Quantity: 50
#     Total Spent: $850.00
#   - Escargots de Bourgogne
#     Total Quantity: 30
#     Total Spent: $318.00
#   - Pâté chinois
#     Total Quantity: 36
#     Total Spent: $864.00
#   - Chef Anton's Cajun Seasoning
#     Total Quantity: 50
#     Total Spent: $1100.00
#   - Lakkalikööri
#     Total Quantity: 68
#     Total Spent: $1159.20
#   - Tunnbröd
#     Total Quantity: 30
#     Total Spent: $270.00
#   - Uncle Bob's Organic Dried Pears
#     Total Quantity: 60
#     Total Spent: $1800.00
#   - Scottish Longbreads
#     Total Quantity: 21
#     Total Spent: $210.00
#   - Röd Kaviar
#     Total Quantity: 59
#     Total Spent: $885.00
#   - Jack's New England Clam Chowder
#     Total Quantity: 72
#     Total Spent: $646.05
#   - Chartreuse verte
#     Total Quantity: 46
#     Total Spent: $828.00
#   - Gula Malacca
#     Total Quantity: 10
#     Total Spent: $194.50
#   - Thüringer Rostbratwurst
#     Total Quantity: 50
#     Total Spent: $6189.50
#   - Sirop d'érable
#     Total Quantity: 30
#     Total Spent: $855.00
#
# Customer: France restauration
# Products purchased: 6
#   - Louisiana Fiery Hot Pepper Sauce
#     Total Quantity: 12
#     Total Spent: $252.60
#   - Tarte au sucre
#     Total Quantity: 10
#     Total Spent: $493.00
#   - Lakkalikööri
#     Total Quantity: 20
#     Total Spent: $360.00
#   - Manjimup Dried Apples
#     Total Quantity: 3
#     Total Spent: $159.00
#   - Pavlova
#     Total Quantity: 10
#     Total Spent: $174.50
#   - Thüringer Rostbratwurst
#     Total Quantity: 14
#     Total Spent: $1733.06
#
# Customer: Franchi S.p.A.
# Products purchased: 10
#   - Boston Crab Meat
#     Total Quantity: 1
#     Total Spent: $18.40
#   - Manjimup Dried Apples
#     Total Quantity: 10
#     Total Spent: $530.00
#   - Gumbär Gummibärchen
#     Total Quantity: 2
#     Total Spent: $49.80
#   - Longlife Tofu
#     Total Quantity: 5
#     Total Spent: $50.00
#   - Teatime Chocolate Biscuits
#     Total Quantity: 5
#     Total Spent: $46.00
#   - Carnarvon Tigers
#     Total Quantity: 8
#     Total Spent: $500.00
#   - Camembert Pierrot
#     Total Quantity: 4
#     Total Spent: $136.00
#   - Zaanse koeken
#     Total Quantity: 5
#     Total Spent: $47.50
#   - Rogede sild
#     Total Quantity: 4
#     Total Spent: $38.00
#   - Original Frankfurter grüne Soße
#     Total Quantity: 10
#     Total Spent: $130.00
#
# Customer: Frankenversand
# Products purchased: 33
#   - Escargots de Bourgogne
#     Total Quantity: 30
#     Total Spent: $397.50
#   - Spegesild
#     Total Quantity: 60
#     Total Spent: $720.00
#   - Pavlova
#     Total Quantity: 30
#     Total Spent: $523.50
#   - Rhönbräu Klosterbier
#     Total Quantity: 74
#     Total Spent: $573.50
#   - Flotemysost
#     Total Quantity: 120
#     Total Spent: $2322.00
#   - Lakkalikööri
#     Total Quantity: 15
#     Total Spent: $216.00
#   - Mozzarella di Giovanni
#     Total Quantity: 46
#     Total Spent: $1278.80
#   - Teatime Chocolate Biscuits
#     Total Quantity: 65
#     Total Spent: $598.00
#   - Tunnbröd
#     Total Quantity: 112
#     Total Spent: $864.00
#   - Jack's New England Clam Chowder
#     Total Quantity: 20
#     Total Spent: $193.00
#   - Tourtière
#     Total Quantity: 50
#     Total Spent: $372.50
#   - Gumbär Gummibärchen
#     Total Quantity: 24
#     Total Spent: $597.60
#   - Sir Rodney's Scones
#     Total Quantity: 117
#     Total Spent: $1170.00
#   - Steeleye Stout
#     Total Quantity: 30
#     Total Spent: $540.00
#   - Gravad lax
#     Total Quantity: 28
#     Total Spent: $582.40
#   - Tarte au sucre
#     Total Quantity: 15
#     Total Spent: $739.50
#   - Nord-Ost Matjeshering
#     Total Quantity: 20
#     Total Spent: $517.80
#   - Wimmers gute Semmelknödel
#     Total Quantity: 30
#     Total Spent: $997.50
#   - Röd Kaviar
#     Total Quantity: 70
#     Total Spent: $990.00
#   - Inlagd Sill
#     Total Quantity: 60
#     Total Spent: $912.00
#   - Chang
#     Total Quantity: 24
#     Total Spent: $364.80
#   - Raclette Courdavault
#     Total Quantity: 100
#     Total Spent: $4400.00
#   - Original Frankfurter grüne Soße
#     Total Quantity: 15
#     Total Spent: $195.00
#   - Gudbrandsdalsost
#     Total Quantity: 25
#     Total Spent: $900.00
#   - Boston Crab Meat
#     Total Quantity: 50
#     Total Spent: $735.00
#   - Pâté chinois
#     Total Quantity: 40
#     Total Spent: $768.00
#   - Tofu
#     Total Quantity: 51
#     Total Spent: $1185.75
#   - Gorgonzola Telino
#     Total Quantity: 56
#     Total Spent: $560.00
#   - Thüringer Rostbratwurst
#     Total Quantity: 14
#     Total Spent: $1733.06
#   - Laughing Lumberjack Lager
#     Total Quantity: 25
#     Total Spent: $350.00
#   - Perth Pasties
#     Total Quantity: 10
#     Total Spent: $328.00
#   - Guaraná Fantástica
#     Total Quantity: 43
#     Total Spent: $193.50
#   - Camembert Pierrot
#     Total Quantity: 56
#     Total Spent: $1904.00
#
# Customer: Furia Bacalhau e Frutos do Mar
# Products purchased: 16
#   - Lakkalikööri
#     Total Quantity: 10
#     Total Spent: $180.00
#   - Original Frankfurter grüne Soße
#     Total Quantity: 7
#     Total Spent: $72.80
#   - Raclette Courdavault
#     Total Quantity: 9
#     Total Spent: $396.00
#   - Tourtière
#     Total Quantity: 20
#     Total Spent: $118.00
#   - Steeleye Stout
#     Total Quantity: 20
#     Total Spent: $360.00
#   - Pavlova
#     Total Quantity: 40
#     Total Spent: $698.00
#   - Ikura
#     Total Quantity: 24
#     Total Spent: $744.00
#   - Chocolade
#     Total Quantity: 6
#     Total Spent: $76.50
#   - Gnocchi di nonna Alice
#     Total Quantity: 42
#     Total Spent: $1368.00
#   - Ipoh Coffee
#     Total Quantity: 3
#     Total Spent: $110.40
#   - Scottish Longbreads
#     Total Quantity: 10
#     Total Spent: $100.00
#   - Gula Malacca
#     Total Quantity: 55
#     Total Spent: $1010.50
#   - Louisiana Fiery Hot Pepper Sauce
#     Total Quantity: 55
#     Total Spent: $987.75
#   - Guaraná Fantástica
#     Total Quantity: 10
#     Total Spent: $36.00
#   - Chef Anton's Cajun Seasoning
#     Total Quantity: 16
#     Total Spent: $281.60
#   - Camembert Pierrot
#     Total Quantity: 22
#     Total Spent: $612.00
#
# Customer: GROSELLA-Restaurante
# Products purchased: 4
#   - Ikura
#     Total Quantity: 10
#     Total Spent: $310.00
#   - Rhönbräu Klosterbier
#     Total Quantity: 10
#     Total Spent: $77.50
#   - Mozzarella di Giovanni
#     Total Quantity: 4
#     Total Spent: $111.20
#   - Thüringer Rostbratwurst
#     Total Quantity: 10
#     Total Spent: $990.00
#
# Customer: Galería del gastrónomo
# Products purchased: 8
#   - NuNuCa Nuß-Nougat-Creme
#     Total Quantity: 5
#     Total Spent: $70.00
#   - Gnocchi di nonna Alice
#     Total Quantity: 5
#     Total Spent: $152.00
#   - Wimmers gute Semmelknödel
#     Total Quantity: 7
#     Total Spent: $186.20
#   - Louisiana Fiery Hot Pepper Sauce
#     Total Quantity: 5
#     Total Spent: $84.00
#   - Ikura
#     Total Quantity: 5
#     Total Spent: $155.00
#   - Original Frankfurter grüne Soße
#     Total Quantity: 5
#     Total Spent: $52.00
#   - Lakkalikööri
#     Total Quantity: 5
#     Total Spent: $90.00
#   - Zaanse koeken
#     Total Quantity: 5
#     Total Spent: $47.50
#
# Customer: Godos Cocina Típica
# Products purchased: 21
#   - Valkoinen suklaa
#     Total Quantity: 9
#     Total Spent: $146.25
#   - Thüringer Rostbratwurst
#     Total Quantity: 20
#     Total Spent: $2475.80
#   - Chang
#     Total Quantity: 20
#     Total Spent: $380.00
#   - Boston Crab Meat
#     Total Quantity: 40
#     Total Spent: $588.00
#   - Ikura
#     Total Quantity: 10
#     Total Spent: $310.00
#   - Guaraná Fantástica
#     Total Quantity: 12
#     Total Spent: $54.00
#   - Sir Rodney's Scones
#     Total Quantity: 6
#     Total Spent: $60.00
#   - Scottish Longbreads
#     Total Quantity: 33
#     Total Spent: $375.00
#   - Sirop d'érable
#     Total Quantity: 10
#     Total Spent: $285.00
#   - Alice Mutton
#     Total Quantity: 20
#     Total Spent: $780.00
#   - Laughing Lumberjack Lager
#     Total Quantity: 15
#     Total Spent: $210.00
#   - Outback Lager
#     Total Quantity: 4
#     Total Spent: $60.00
#   - Teatime Chocolate Biscuits
#     Total Quantity: 10
#     Total Spent: $92.00
#   - Pâté chinois
#     Total Quantity: 14
#     Total Spent: $336.00
#   - Manjimup Dried Apples
#     Total Quantity: 40
#     Total Spent: $2120.00
#   - Louisiana Fiery Hot Pepper Sauce
#     Total Quantity: 51
#     Total Spent: $946.05
#   - Tarte au sucre
#     Total Quantity: 20
#     Total Spent: $986.00
#   - Wimmers gute Semmelknödel
#     Total Quantity: 24
#     Total Spent: $798.00
#   - Chai
#     Total Quantity: 10
#     Total Spent: $180.00
#   - Inlagd Sill
#     Total Quantity: 18
#     Total Spent: $342.00
#   - Camembert Pierrot
#     Total Quantity: 9
#     Total Spent: $306.00
#
# Customer: Gourmet Lanchonetes
# Products purchased: 17
#   - Gnocchi di nonna Alice
#     Total Quantity: 20
#     Total Spent: $760.00
#   - Manjimup Dried Apples
#     Total Quantity: 28
#     Total Spent: $1484.00
#   - Zaanse koeken
#     Total Quantity: 15
#     Total Spent: $142.50
#   - Camembert Pierrot
#     Total Quantity: 10
#     Total Spent: $340.00
#   - Lakkalikööri
#     Total Quantity: 20
#     Total Spent: $360.00
#   - Queso Manchego La Pastora
#     Total Quantity: 4
#     Total Spent: $152.00
#   - Grandma's Boysenberry Spread
#     Total Quantity: 30
#     Total Spent: $750.00
#   - Uncle Bob's Organic Dried Pears
#     Total Quantity: 3
#     Total Spent: $90.00
#   - Raclette Courdavault
#     Total Quantity: 20
#     Total Spent: $880.00
#   - Rhönbräu Klosterbier
#     Total Quantity: 20
#     Total Spent: $155.00
#   - Ikura
#     Total Quantity: 20
#     Total Spent: $620.00
#   - Northwoods Cranberry Sauce
#     Total Quantity: 40
#     Total Spent: $1600.00
#   - Singaporean Hokkien Fried Mee
#     Total Quantity: 40
#     Total Spent: $560.00
#   - Jack's New England Clam Chowder
#     Total Quantity: 4
#     Total Spent: $38.60
#   - Nord-Ost Matjeshering
#     Total Quantity: 17
#     Total Spent: $440.13
#   - Chang
#     Total Quantity: 10
#     Total Spent: $190.00
#   - Gorgonzola Telino
#     Total Quantity: 14
#     Total Spent: $140.00
#
# Customer: Great Lakes Food Market
# Products purchased: 20
#   - Teatime Chocolate Biscuits
#     Total Quantity: 30
#     Total Spent: $276.00
#   - Gula Malacca
#     Total Quantity: 28
#     Total Spent: $544.60
#   - Geitost
#     Total Quantity: 8
#     Total Spent: $20.00
#   - Raclette Courdavault
#     Total Quantity: 30
#     Total Spent: $1650.00
#   - Inlagd Sill
#     Total Quantity: 30
#     Total Spent: $570.00
#   - Thüringer Rostbratwurst
#     Total Quantity: 2
#     Total Spent: $247.58
#   - Zaanse koeken
#     Total Quantity: 6
#     Total Spent: $57.00
#   - Mozzarella di Giovanni
#     Total Quantity: 9
#     Total Spent: $313.20
#   - Gnocchi di nonna Alice
#     Total Quantity: 14
#     Total Spent: $532.00
#   - Steeleye Stout
#     Total Quantity: 4
#     Total Spent: $72.00
#   - Flotemysost
#     Total Quantity: 15
#     Total Spent: $322.50
#   - Tarte au sucre
#     Total Quantity: 20
#     Total Spent: $986.00
#   - Camembert Pierrot
#     Total Quantity: 15
#     Total Spent: $510.00
#   - Queso Cabrales
#     Total Quantity: 3
#     Total Spent: $63.00
#   - Wimmers gute Semmelknödel
#     Total Quantity: 28
#     Total Spent: $931.00
#   - Outback Lager
#     Total Quantity: 15
#     Total Spent: $225.00
#   - Sir Rodney's Scones
#     Total Quantity: 32
#     Total Spent: $320.00
#   - Chai
#     Total Quantity: 8
#     Total Spent: $144.00
#   - Côte de Blaye
#     Total Quantity: 45
#     Total Spent: $11857.50
#   - Tofu
#     Total Quantity: 3
#     Total Spent: $69.75
#
# Customer: HILARION-Abastos
# Products purchased: 33
#   - Perth Pasties
#     Total Quantity: 70
#     Total Spent: $1834.00
#   - Chang
#     Total Quantity: 50
#     Total Spent: $950.00
#   - Rössle Sauerkraut
#     Total Quantity: 20
#     Total Spent: $912.00
#   - Raclette Courdavault
#     Total Quantity: 95
#     Total Spent: $4565.00
#   - Gula Malacca
#     Total Quantity: 10
#     Total Spent: $194.50
#   - Outback Lager
#     Total Quantity: 12
#     Total Spent: $144.00
#   - Schoggi Schokolade
#     Total Quantity: 25
#     Total Spent: $877.50
#   - Flotemysost
#     Total Quantity: 30
#     Total Spent: $645.00
#   - Wimmers gute Semmelknödel
#     Total Quantity: 43
#     Total Spent: $1429.75
#   - Gudbrandsdalsost
#     Total Quantity: 50
#     Total Spent: $1742.40
#   - Singaporean Hokkien Fried Mee
#     Total Quantity: 30
#     Total Spent: $420.00
#   - Pâté chinois
#     Total Quantity: 2
#     Total Spent: $38.40
#   - Spegesild
#     Total Quantity: 28
#     Total Spent: $268.80
#   - Scottish Longbreads
#     Total Quantity: 30
#     Total Spent: $300.00
#   - NuNuCa Nuß-Nougat-Creme
#     Total Quantity: 15
#     Total Spent: $210.00
#   - Chai
#     Total Quantity: 20
#     Total Spent: $360.00
#   - Manjimup Dried Apples
#     Total Quantity: 45
#     Total Spent: $2120.00
#   - Boston Crab Meat
#     Total Quantity: 65
#     Total Spent: $1196.00
#   - Jack's New England Clam Chowder
#     Total Quantity: 54
#     Total Spent: $521.10
#   - Chartreuse verte
#     Total Quantity: 6
#     Total Spent: $86.40
#   - Longlife Tofu
#     Total Quantity: 16
#     Total Spent: $128.00
#   - Guaraná Fantástica
#     Total Quantity: 39
#     Total Spent: $175.50
#   - Gumbär Gummibärchen
#     Total Quantity: 21
#     Total Spent: $655.83
#   - Gorgonzola Telino
#     Total Quantity: 20
#     Total Spent: $250.00
#   - Original Frankfurter grüne Soße
#     Total Quantity: 15
#     Total Spent: $156.00
#   - Escargots de Bourgogne
#     Total Quantity: 12
#     Total Spent: $159.00
#   - Mascarpone Fabioli
#     Total Quantity: 4
#     Total Spent: $128.00
#   - Konbu
#     Total Quantity: 68
#     Total Spent: $408.00
#   - Rhönbräu Klosterbier
#     Total Quantity: 106
#     Total Spent: $765.70
#   - Steeleye Stout
#     Total Quantity: 40
#     Total Spent: $720.00
#   - Nord-Ost Matjeshering
#     Total Quantity: 30
#     Total Spent: $776.70
#   - Ravioli Angelo
#     Total Quantity: 20
#     Total Spent: $390.00
#   - Queso Cabrales
#     Total Quantity: 5
#     Total Spent: $84.00
#
# Customer: Hanari Carnes
# Products purchased: 23
#   - Original Frankfurter grüne Soße
#     Total Quantity: 70
#     Total Spent: $910.00
#   - Gudbrandsdalsost
#     Total Quantity: 30
#     Total Spent: $1080.00
#   - Inlagd Sill
#     Total Quantity: 40
#     Total Spent: $760.00
#   - Côte de Blaye
#     Total Quantity: 69
#     Total Spent: $18181.50
#   - Sirop d'érable
#     Total Quantity: 10
#     Total Spent: $285.00
#   - Filo Mix
#     Total Quantity: 12
#     Total Spent: $84.00
#   - Louisiana Fiery Hot Pepper Sauce
#     Total Quantity: 72
#     Total Spent: $1451.85
#   - Flotemysost
#     Total Quantity: 9
#     Total Spent: $193.50
#   - Maxilaku
#     Total Quantity: 40
#     Total Spent: $640.00
#   - Ikura
#     Total Quantity: 70
#     Total Spent: $2170.00
#   - Scottish Longbreads
#     Total Quantity: 20
#     Total Spent: $250.00
#   - Gnocchi di nonna Alice
#     Total Quantity: 20
#     Total Spent: $760.00
#   - Manjimup Dried Apples
#     Total Quantity: 35
#     Total Spent: $1484.00
#   - Konbu
#     Total Quantity: 40
#     Total Spent: $240.00
#   - Gorgonzola Telino
#     Total Quantity: 65
#     Total Spent: $762.50
#   - Jack's New England Clam Chowder
#     Total Quantity: 10
#     Total Spent: $77.00
#   - Queso Cabrales
#     Total Quantity: 15
#     Total Spent: $315.00
#   - Ipoh Coffee
#     Total Quantity: 30
#     Total Spent: $1380.00
#   - Chartreuse verte
#     Total Quantity: 42
#     Total Spent: $604.80
#   - Teatime Chocolate Biscuits
#     Total Quantity: 35
#     Total Spent: $322.00
#   - Alice Mutton
#     Total Quantity: 15
#     Total Spent: $585.00
#   - Carnarvon Tigers
#     Total Quantity: 20
#     Total Spent: $1250.00
#   - Guaraná Fantástica
#     Total Quantity: 70
#     Total Spent: $315.00
#
# Customer: Hungry Coyote Import Store
# Products purchased: 8
#   - Alice Mutton
#     Total Quantity: 2
#     Total Spent: $62.40
#   - Tofu
#     Total Quantity: 15
#     Total Spent: $279.00
#   - Sir Rodney's Marmalade
#     Total Quantity: 21
#     Total Spent: $1701.00
#   - Tarte au sucre
#     Total Quantity: 10
#     Total Spent: $394.00
#   - Geitost
#     Total Quantity: 20
#     Total Spent: $40.00
#   - Konbu
#     Total Quantity: 10
#     Total Spent: $48.00
#   - Tourtière
#     Total Quantity: 14
#     Total Spent: $88.80
#   - Röd Kaviar
#     Total Quantity: 30
#     Total Spent: $450.00
#
# Customer: Hungry Owl All-Night Grocers
# Products purchased: 36
#   - Mishi Kobe Niku
#     Total Quantity: 50
#     Total Spent: $4850.00
#   - Camembert Pierrot
#     Total Quantity: 6
#     Total Spent: $163.20
#   - Flotemysost
#     Total Quantity: 103
#     Total Spent: $1986.60
#   - Boston Crab Meat
#     Total Quantity: 40
#     Total Spent: $736.00
#   - Rhönbräu Klosterbier
#     Total Quantity: 20
#     Total Spent: $155.00
#   - Manjimup Dried Apples
#     Total Quantity: 51
#     Total Spent: $2194.20
#   - Mascarpone Fabioli
#     Total Quantity: 41
#     Total Spent: $1273.60
#   - Pavlova
#     Total Quantity: 36
#     Total Spent: $628.20
#   - Inlagd Sill
#     Total Quantity: 46
#     Total Spent: $722.00
#   - Tofu
#     Total Quantity: 70
#     Total Spent: $1627.50
#   - Sasquatch Ale
#     Total Quantity: 30
#     Total Spent: $420.00
#   - Jack's New England Clam Chowder
#     Total Quantity: 110
#     Total Spent: $1061.50
#   - Carnarvon Tigers
#     Total Quantity: 33
#     Total Spent: $2062.50
#   - Outback Lager
#     Total Quantity: 30
#     Total Spent: $360.00
#   - Original Frankfurter grüne Soße
#     Total Quantity: 35
#     Total Spent: $455.00
#   - Grandma's Boysenberry Spread
#     Total Quantity: 30
#     Total Spent: $600.00
#   - Raclette Courdavault
#     Total Quantity: 112
#     Total Spent: $5830.00
#   - Chartreuse verte
#     Total Quantity: 3
#     Total Spent: $54.00
#   - Valkoinen suklaa
#     Total Quantity: 40
#     Total Spent: $520.00
#   - Tarte au sucre
#     Total Quantity: 15
#     Total Spent: $591.00
#   - Singaporean Hokkien Fried Mee
#     Total Quantity: 22
#     Total Spent: $302.40
#   - Gnocchi di nonna Alice
#     Total Quantity: 30
# ...
#     Total Spent: $70.00
#   - Boston Crab Meat
#     Total Quantity: 10
#     Total Spent: $184.00
#   - Laughing Lumberjack Lager
#     Total Quantity: 3
#     Total Spent: $42.00
#   - Rössle Sauerkraut
#     Total Quantity: 10
#     Total Spent: $456.00
#   - Thüringer Rostbratwurst
#     Total Quantity: 6
#     Total Spent: $742.74
#   - Chai
#     Total Quantity: 4
#     Total Spent: $72.00
#   - Gula Malacca
#     Total Quantity: 10
#     Total Spent: $194.50
#
# Customer: Toms Spezialitäten
# Products purchased: 11
#   - Guaraná Fantástica
#     Total Quantity: 20
#     Total Spent: $72.00
#   - Manjimup Dried Apples
#     Total Quantity: 40
#     Total Spent: $1696.00
#   - Teatime Chocolate Biscuits
#     Total Quantity: 39
#     Total Spent: $307.50
#   - Maxilaku
#     Total Quantity: 40
#     Total Spent: $800.00
#   - Gnocchi di nonna Alice
#     Total Quantity: 28
#     Total Spent: $1064.00
#   - Sasquatch Ale
#     Total Quantity: 30
#     Total Spent: $364.00
#   - Ravioli Angelo
#     Total Quantity: 15
#     Total Spent: $234.00
#   - Filo Mix
#     Total Quantity: 15
#     Total Spent: $84.00
#   - Gorgonzola Telino
#     Total Quantity: 3
#     Total Spent: $30.00
#   - Tofu
#     Total Quantity: 9
#     Total Spent: $167.40
#   - Jack's New England Clam Chowder
#     Total Quantity: 14
#     Total Spent: $135.10
#
# Customer: Tortuga Restaurante
# Products purchased: 24
#   - Rössle Sauerkraut
#     Total Quantity: 14
#     Total Spent: $509.60
#   - Chai
#     Total Quantity: 10
#     Total Spent: $180.00
#   - Carnarvon Tigers
#     Total Quantity: 12
#     Total Spent: $600.00
#   - Flotemysost
#     Total Quantity: 2
#     Total Spent: $34.40
#   - Outback Lager
#     Total Quantity: 12
#     Total Spent: $180.00
#   - Tourtière
#     Total Quantity: 10
#     Total Spent: $74.50
#   - Lakkalikööri
#     Total Quantity: 30
#     Total Spent: $432.00
#   - Côte de Blaye
#     Total Quantity: 15
#     Total Spent: $3952.50
#   - Guaraná Fantástica
#     Total Quantity: 15
#     Total Spent: $58.50
#   - Ikura
#     Total Quantity: 17
#     Total Spent: $434.00
#   - Raclette Courdavault
#     Total Quantity: 10
#     Total Spent: $440.00
#   - Rhönbräu Klosterbier
#     Total Quantity: 6
#     Total Spent: $37.20
#   - Queso Cabrales
#     Total Quantity: 15
#     Total Spent: $315.00
#   - Ipoh Coffee
#     Total Quantity: 5
#     Total Spent: $230.00
#   - Geitost
#     Total Quantity: 30
#     Total Spent: $75.00
#   - Maxilaku
#     Total Quantity: 30
#     Total Spent: $480.00
#   - Teatime Chocolate Biscuits
#     Total Quantity: 7
#     Total Spent: $64.40
#   - Gorgonzola Telino
#     Total Quantity: 20
#     Total Spent: $250.00
#   - Chartreuse verte
#     Total Quantity: 20
#     Total Spent: $360.00
#   - Alice Mutton
#     Total Quantity: 18
#     Total Spent: $639.60
#   - Gula Malacca
#     Total Quantity: 51
#     Total Spent: $991.95
#   - Scottish Longbreads
#     Total Quantity: 20
#     Total Spent: $250.00
#   - Vegie-spread
#     Total Quantity: 5
#     Total Spent: $175.50
#   - Konbu
#     Total Quantity: 10
#     Total Spent: $48.00
#
# Customer: Tradição Hipermercados
# Products purchased: 13
#   - Escargots de Bourgogne
#     Total Quantity: 30
#     Total Spent: $397.50
#   - Gorgonzola Telino
#     Total Quantity: 20
#     Total Spent: $200.00
#   - Chartreuse verte
#     Total Quantity: 28
#     Total Spent: $504.00
#   - Nord-Ost Matjeshering
#     Total Quantity: 20
#     Total Spent: $517.80
#   - Tarte au sucre
#     Total Quantity: 10
#     Total Spent: $493.00
#   - Scottish Longbreads
#     Total Quantity: 24
#     Total Spent: $300.00
#   - Mozzarella di Giovanni
#     Total Quantity: 15
#     Total Spent: $522.00
#   - Chef Anton's Cajun Seasoning
#     Total Quantity: 20
#     Total Spent: $440.00
#   - Grandma's Boysenberry Spread
#     Total Quantity: 6
#     Total Spent: $150.00
#   - Pâté chinois
#     Total Quantity: 20
#     Total Spent: $480.00
#   - Thüringer Rostbratwurst
#     Total Quantity: 8
#     Total Spent: $990.32
#   - Sir Rodney's Marmalade
#     Total Quantity: 20
#     Total Spent: $1296.00
#   - Camembert Pierrot
#     Total Quantity: 30
#     Total Spent: $1020.00
#
# Customer: Trail's Head Gourmet Provisioners
# Products purchased: 8
#   - Original Frankfurter grüne Soße
#     Total Quantity: 18
#     Total Spent: $234.00
#   - Wimmers gute Semmelknödel
#     Total Quantity: 6
#     Total Spent: $199.50
#   - Chartreuse verte
#     Total Quantity: 10
#     Total Spent: $180.00
#   - Boston Crab Meat
#     Total Quantity: 2
#     Total Spent: $36.80
#   - Tarte au sucre
#     Total Quantity: 13
#     Total Spent: $640.90
#   - Rhönbräu Klosterbier
#     Total Quantity: 20
#     Total Spent: $155.00
#   - Outback Lager
#     Total Quantity: 6
#     Total Spent: $90.00
#   - Geitost
#     Total Quantity: 14
#     Total Spent: $35.00
#
# Customer: Vaffeljernet
# Products purchased: 23
#   - Guaraná Fantástica
#     Total Quantity: 50
#     Total Spent: $202.50
#   - Ikura
#     Total Quantity: 43
#     Total Spent: $1333.00
#   - Aniseed Syrup
#     Total Quantity: 14
#     Total Spent: $140.00
#   - Boston Crab Meat
#     Total Quantity: 70
#     Total Spent: $1214.00
#   - Tarte au sucre
#     Total Quantity: 15
#     Total Spent: $739.50
#   - Scottish Longbreads
#     Total Quantity: 60
#     Total Spent: $600.00
#   - Valkoinen suklaa
#     Total Quantity: 25
#     Total Spent: $325.00
#   - Lakkalikööri
#     Total Quantity: 35
#     Total Spent: $504.00
#   - Steeleye Stout
#     Total Quantity: 10
#     Total Spent: $180.00
#   - Sasquatch Ale
#     Total Quantity: 50
#     Total Spent: $599.20
#   - Louisiana Fiery Hot Pepper Sauce
#     Total Quantity: 15
#     Total Spent: $252.00
#   - Jack's New England Clam Chowder
#     Total Quantity: 30
#     Total Spent: $289.50
#   - Thüringer Rostbratwurst
#     Total Quantity: 18
#     Total Spent: $1782.00
#   - Tourtière
#     Total Quantity: 68
#     Total Spent: $478.70
#   - Rogede sild
#     Total Quantity: 30
#     Total Spent: $228.00
#   - Filo Mix
#     Total Quantity: 15
#     Total Spent: $105.00
#   - Raclette Courdavault
#     Total Quantity: 18
#     Total Spent: $990.00
#   - Rössle Sauerkraut
#     Total Quantity: 60
#     Total Spent: $2736.00
#   - Sirop d'érable
#     Total Quantity: 20
#     Total Spent: $570.00
#   - Vegie-spread
#     Total Quantity: 40
#     Total Spent: $1756.00
#   - Flotemysost
#     Total Quantity: 30
#     Total Spent: $516.00
#   - Uncle Bob's Organic Dried Pears
#     Total Quantity: 10
#     Total Spent: $300.00
#   - Original Frankfurter grüne Soße
#     Total Quantity: 66
#     Total Spent: $803.40
#
# Customer: Victuailles en stock
# Products purchased: 22
#   - Ravioli Angelo
#     Total Quantity: 15
#     Total Spent: $234.00
#   - Chocolade
#     Total Quantity: 8
#     Total Spent: $102.00
#   - Outback Lager
#     Total Quantity: 30
#     Total Spent: $450.00
#   - Mozzarella di Giovanni
#     Total Quantity: 40
#     Total Spent: $1112.00
#   - Louisiana Fiery Hot Pepper Sauce
#     Total Quantity: 22
#     Total Spent: $378.10
#   - Uncle Bob's Organic Dried Pears
#     Total Quantity: 26
#     Total Spent: $684.00
#   - Longlife Tofu
#     Total Quantity: 15
#     Total Spent: $150.00
#   - Chang
#     Total Quantity: 20
#     Total Spent: $380.00
#   - Ipoh Coffee
#     Total Quantity: 20
#     Total Spent: $920.00
#   - Gustaf's Knäckebröd
#     Total Quantity: 6
#     Total Spent: $100.80
#   - Filo Mix
#     Total Quantity: 8
#     Total Spent: $44.80
#   - Scottish Longbreads
#     Total Quantity: 10
#     Total Spent: $100.00
#   - NuNuCa Nuß-Nougat-Creme
#     Total Quantity: 20
#     Total Spent: $280.00
#   - Ikura
#     Total Quantity: 40
#     Total Spent: $992.00
#   - Steeleye Stout
#     Total Quantity: 30
#     Total Spent: $540.00
#   - Jack's New England Clam Chowder
#     Total Quantity: 20
#     Total Spent: $193.00
#   - Geitost
#     Total Quantity: 4
#     Total Spent: $10.00
#   - Manjimup Dried Apples
#     Total Quantity: 4
#     Total Spent: $212.00
#   - Tourtière
#     Total Quantity: 6
#     Total Spent: $35.40
#   - Sirop d'érable
#     Total Quantity: 30
#     Total Spent: $855.00
#   - Tarte au sucre
#     Total Quantity: 40
#     Total Spent: $1972.00
#   - Spegesild
#     Total Quantity: 20
#     Total Spent: $192.00
#
# Customer: Vins et alcools Chevalier
# Products purchased: 9
#   - Inlagd Sill
#     Total Quantity: 6
#     Total Spent: $114.00
#   - Filo Mix
#     Total Quantity: 18
#     Total Spent: $126.00
#   - Jack's New England Clam Chowder
#     Total Quantity: 12
#     Total Spent: $115.80
#   - Flotemysost
#     Total Quantity: 20
#     Total Spent: $344.00
#   - Queso Cabrales
#     Total Quantity: 12
#     Total Spent: $168.00
#   - Singaporean Hokkien Fried Mee
#     Total Quantity: 10
#     Total Spent: $98.00
#   - Mozzarella di Giovanni
#     Total Quantity: 12
#     Total Spent: $368.60
#   - Gnocchi di nonna Alice
#     Total Quantity: 4
#     Total Spent: $121.60
#   - Konbu
#     Total Quantity: 4
#     Total Spent: $24.00
#
# Customer: Wartian Herkku
# Products purchased: 28
#   - Sir Rodney's Scones
#     Total Quantity: 10
#     Total Spent: $80.00
#   - Gnocchi di nonna Alice
#     Total Quantity: 50
#     Total Spent: $1900.00
#   - Steeleye Stout
#     Total Quantity: 6
#     Total Spent: $108.00
#   - Teatime Chocolate Biscuits
#     Total Quantity: 20
#     Total Spent: $146.00
#   - Camembert Pierrot
#     Total Quantity: 24
#     Total Spent: $816.00
#   - Ipoh Coffee
#     Total Quantity: 25
#     Total Spent: $920.00
#   - Pavlova
#     Total Quantity: 14
#     Total Spent: $244.30
#   - Konbu
#     Total Quantity: 30
#     Total Spent: $180.00
#   - Thüringer Rostbratwurst
#     Total Quantity: 10
#     Total Spent: $1237.90
#   - Gorgonzola Telino
#     Total Quantity: 30
#     Total Spent: $375.00
#   - Queso Manchego La Pastora
#     Total Quantity: 12
#     Total Spent: $364.80
#   - Gudbrandsdalsost
#     Total Quantity: 10
#     Total Spent: $360.00
#   - Tourtière
#     Total Quantity: 3
#     Total Spent: $22.35
#   - Gustaf's Knäckebröd
#     Total Quantity: 24
#     Total Spent: $504.00
#   - Queso Cabrales
#     Total Quantity: 15
#     Total Spent: $315.00
#   - Sirop d'érable
#     Total Quantity: 25
#     Total Spent: $570.00
#   - Inlagd Sill
#     Total Quantity: 30
#     Total Spent: $456.00
#   - Ravioli Angelo
#     Total Quantity: 20
#     Total Spent: $312.00
#   - Escargots de Bourgogne
#     Total Quantity: 6
#     Total Spent: $79.50
#   - Flotemysost
#     Total Quantity: 100
#     Total Spent: $1720.00
#   - Longlife Tofu
#     Total Quantity: 35
#     Total Spent: $350.00
#   - Rogede sild
#     Total Quantity: 40
#     Total Spent: $380.00
#   - Chai
#     Total Quantity: 18
#     Total Spent: $324.00
#   - Chef Anton's Cajun Seasoning
#     Total Quantity: 25
#     Total Spent: $550.00
#   - Tofu
#     Total Quantity: 35
#     Total Spent: $674.25
#   - Perth Pasties
#     Total Quantity: 75
#     Total Spent: $1965.00
#   - Chartreuse verte
#     Total Quantity: 20
#     Total Spent: $288.00
#   - Raclette Courdavault
#     Total Quantity: 25
#     Total Spent: $1375.00
#
# Customer: Wellington Importadora
# Products purchased: 16
#   - Carnarvon Tigers
#     Total Quantity: 8
#     Total Spent: $500.00
#   - Teatime Chocolate Biscuits
#     Total Quantity: 24
#     Total Spent: $220.80
#   - Konbu
#     Total Quantity: 2
#     Total Spent: $9.60
#   - Raclette Courdavault
#     Total Quantity: 15
#     Total Spent: $825.00
#   - Perth Pasties
#     Total Quantity: 15
#     Total Spent: $393.00
#   - Tunnbröd
#     Total Quantity: 8
#     Total Spent: $72.00
#   - Original Frankfurter grüne Soße
#     Total Quantity: 12
#     Total Spent: $124.80
#   - Outback Lager
#     Total Quantity: 11
#     Total Spent: $141.00
#   - Röd Kaviar
#     Total Quantity: 20
#     Total Spent: $240.00
#   - Chai
#     Total Quantity: 41
#     Total Spent: $738.00
#   - Mishi Kobe Niku
#     Total Quantity: 20
#     Total Spent: $1552.00
#   - Filo Mix
#     Total Quantity: 20
#     Total Spent: $140.00
#   - Spegesild
#     Total Quantity: 21
#     Total Spent: $252.00
#   - Zaanse koeken
#     Total Quantity: 15
#     Total Spent: $142.50
#   - Ipoh Coffee
#     Total Quantity: 20
#     Total Spent: $920.00
#   - NuNuCa Nuß-Nougat-Creme
#     Total Quantity: 15
#     Total Spent: $210.00
#
# Customer: White Clover Markets
# Products purchased: 32
#   - Escargots de Bourgogne
#     Total Quantity: 15
#     Total Spent: $198.75
#   - Original Frankfurter grüne Soße
#     Total Quantity: 30
#     Total Spent: $312.00
#   - Sirop d'érable
#     Total Quantity: 25
#     Total Spent: $712.50
#   - Gnocchi di nonna Alice
#     Total Quantity: 19
#     Total Spent: $722.00
#   - Gula Malacca
#     Total Quantity: 2
#     Total Spent: $31.00
#   - Vegie-spread
#     Total Quantity: 24
#     Total Spent: $1053.60
#   - Spegesild
#     Total Quantity: 18
#     Total Spent: $216.00
#   - Chef Anton's Cajun Seasoning
#     Total Quantity: 35
#     Total Spent: $616.00
#   - Tarte au sucre
#     Total Quantity: 38
#     Total Spent: $1873.40
#   - Sir Rodney's Scones
#     Total Quantity: 52
#     Total Spent: $520.00
#   - Perth Pasties
#     Total Quantity: 10
#     Total Spent: $328.00
#   - Steeleye Stout
#     Total Quantity: 35
#     Total Spent: $630.00
#   - Teatime Chocolate Biscuits
#     Total Quantity: 42
#     Total Spent: $386.40
#   - Raclette Courdavault
#     Total Quantity: 30
#     Total Spent: $1650.00
#   - Rössle Sauerkraut
#     Total Quantity: 5
#     Total Spent: $228.00
#   - Gudbrandsdalsost
#     Total Quantity: 30
#     Total Spent: $1080.00
#   - Röd Kaviar
#     Total Quantity: 15
#     Total Spent: $225.00
#   - Chang
#     Total Quantity: 52
#     Total Spent: $836.00
#   - Inlagd Sill
#     Total Quantity: 35
#     Total Spent: $665.00
#   - Rogede sild
#     Total Quantity: 40
#     Total Spent: $380.00
#   - Carnarvon Tigers
#     Total Quantity: 20
#     Total Spent: $1250.00
#   - Tourtière
#     Total Quantity: 60
#     Total Spent: $447.00
#   - Geitost
#     Total Quantity: 95
#     Total Spent: $207.50
#   - Mishi Kobe Niku
#     Total Quantity: 6
#     Total Spent: $582.00
#   - Alice Mutton
#     Total Quantity: 62
#     Total Spent: $2418.00
#   - Côte de Blaye
#     Total Quantity: 25
#     Total Spent: $6587.50
#   - Northwoods Cranberry Sauce
#     Total Quantity: 70
#     Total Spent: $2240.00
#   - Gumbär Gummibärchen
#     Total Quantity: 15
#     Total Spent: $468.45
#   - Mozzarella di Giovanni
#     Total Quantity: 20
#     Total Spent: $556.00
#   - Pavlova
#     Total Quantity: 38
#     Total Spent: $538.85
#   - Sasquatch Ale
#     Total Quantity: 70
#     Total Spent: $882.00
#   - Rhönbräu Klosterbier
#     Total Quantity: 30
#     Total Spent: $232.50
#
# Customer: Wilman Kala
# Products purchased: 17
#   - Pâté chinois
#     Total Quantity: 5
#     Total Spent: $120.00
#   - Sirop d'érable
#     Total Quantity: 5
#     Total Spent: $142.50
#   - Boston Crab Meat
#     Total Quantity: 12
#     Total Spent: $220.80
#   - Ipoh Coffee
#     Total Quantity: 6
#     Total Spent: $276.00
#   - Louisiana Fiery Hot Pepper Sauce
#     Total Quantity: 10
#     Total Spent: $210.50
#   - Queso Manchego La Pastora
#     Total Quantity: 4
#     Total Spent: $152.00
#   - Lakkalikööri
#     Total Quantity: 10
#     Total Spent: $180.00
#   - Rössle Sauerkraut
#     Total Quantity: 3
#     Total Spent: $136.80
#   - Teatime Chocolate Biscuits
#     Total Quantity: 12
#     Total Spent: $110.40
#   - Sir Rodney's Scones
#     Total Quantity: 20
#     Total Spent: $200.00
#   - Maxilaku
#     Total Quantity: 10
#     Total Spent: $200.00
#   - Guaraná Fantástica
#     Total Quantity: 20
#     Total Spent: $90.00
#   - Northwoods Cranberry Sauce
#     Total Quantity: 10
#     Total Spent: $400.00
#   - Singaporean Hokkien Fried Mee
#     Total Quantity: 6
#     Total Spent: $84.00
#   - Raclette Courdavault
#     Total Quantity: 10
#     Total Spent: $550.00
#   - Pavlova
#     Total Quantity: 3
#     Total Spent: $52.35
#   - Chai
#     Total Quantity: 2
#     Total Spent: $36.00
#
# Customer: Wolski  Zajazd
# Products purchased: 14
#   - Sirop d'érable
#     Total Quantity: 22
#     Total Spent: $627.00
#   - Chai
#     Total Quantity: 6
#     Total Spent: $108.00
#   - Camembert Pierrot
#     Total Quantity: 15
#     Total Spent: $510.00
#   - Tourtière
#     Total Quantity: 3
#     Total Spent: $22.35
#   - Steeleye Stout
#     Total Quantity: 3
#     Total Spent: $54.00
#   - Manjimup Dried Apples
#     Total Quantity: 2
#     Total Spent: $106.00
#   - Scottish Longbreads
#     Total Quantity: 15
#     Total Spent: $187.50
#   - Longlife Tofu
#     Total Quantity: 20
#     Total Spent: $200.00
#   - Chang
#     Total Quantity: 20
#     Total Spent: $380.00
#   - Guaraná Fantástica
#     Total Quantity: 12
#     Total Spent: $54.00
#   - Escargots de Bourgogne
#     Total Quantity: 15
#     Total Spent: $159.00
#   - Rhönbräu Klosterbier
#     Total Quantity: 30
#     Total Spent: $232.50
#   - Tarte au sucre
#     Total Quantity: 12
#     Total Spent: $591.60
#   - Gorgonzola Telino
#     Total Quantity: 30
#     Total Spent: $300.00

# %% [markdown]
# 1D)
#
# This query creates a materialised view by using the $merge operator at the end of an aggregation pipeline, which stores the computed results as a permanent collection rather than just returning temporary results.
#
# The pipeline joins customers with orders, order details, products, and categories to present the characteristics for each customer: total number of orders, total quantity purchased across all products, total revenue, a list of unique product categories ($addToSet to avoid duplicates), and the first and most recent order dates (using $min and $max).
#
# By materialising these pre-computed aggregations into a separate collection, subsequent queries for customer summaries become much faster since the complex calculations don't need to be repeated each time, which is particularly useful for reporting and analytics in large databases.

# %%
# 1D) Create materialised view: customer_sales_summary

# This pipeline aggregates customer purchasing data across all orders, storing results as a new collection

pipeline = [
    {
        # Join customers with their orders
        "$lookup": {
            "from": "orders",
            "localField": "_id",
            "foreignField": "CustomerID",
            "as": "customer_orders"
        }
    },
    {
        # Only include customers who have orders
        "$match": {
            "customer_orders": { "$ne": [] }
        }
    },
    {
        # Flatten orders array
        "$unwind": "$customer_orders"
    },
    {
        # Flatten order details within each order
        "$unwind": "$customer_orders.OrderDetails"
    },
    {
        # Join with products to get category information
        "$lookup": {
            "from": "products",
            "localField": "customer_orders.OrderDetails.ProductID",
            "foreignField": "_id",
            "as": "product_info"
        }
    },
    {
        "$unwind": "$product_info"
    },
    {
        # Join with categories to get category names
        "$lookup": {
            "from": "categories",
            "localField": "product_info.CategoryID",
            "foreignField": "_id",
            "as": "category_info"
        }
    },
    {
        "$unwind": "$category_info"
    },
    {
        # Group by customer to calculate summary statistics
        "$group": {
            "_id": "$_id",
            "CompanyName": { "$first": "$CompanyName" },
            "ContactName": { "$first": "$ContactName" },
            "Country": { "$first": "$Country" },
            "TotalOrders": { "$sum": 1 },
            "TotalQuantityPurchased": { 
                "$sum": "$customer_orders.OrderDetails.Quantity" 
            },
            "TotalRevenue": { 
                "$sum": { 
                    "$multiply": [
                        "$customer_orders.OrderDetails.Quantity",
                        "$customer_orders.OrderDetails.UnitPrice"
                    ]
                }
            },
            "Categories": { 
                "$addToSet": "$category_info.CategoryName" 
            },
            "FirstOrderDate": { 
                "$min": "$customer_orders.OrderDate" 
            },
            "MostRecentOrderDate": { 
                "$max": "$customer_orders.OrderDate" 
            }
        }
    },
    {
        # Sort by total revenue descending
        "$sort": { "TotalRevenue": -1 }
    },
    {
        # Materialize the view by storing results in new collection
        "$merge": {
            "into": "customer_sales_summary",
            "whenMatched": "replace",
            "whenNotMatched": "insert"
        }
    }
]


customers.aggregate(pipeline)

print("Materialized view 'customer_sales_summary' created successfully!")

# Ensure the result is stored as a materialised view collection:
print(f"\nTotal customers in summary: {db.customer_sales_summary.count_documents({})}")
# Out:
# Materialized view 'customer_sales_summary' created successfully!
#
# Total customers in summary: 89
#
# Sample customer summary:
# {'Categories': ['Seafood',
#                 'Grains/Cereals',
#                 'Confections',
#                 'Beverages',
#                 'Condiments',
#                 'Dairy Products',
#                 'Meat/Poultry',
#                 'Produce'],
#  'CompanyName': 'QUICK-Stop',
#  'ContactName': 'Horst Kloss',
#  'Country': 'Germany',
#  'FirstOrderDate': datetime.datetime(1996, 8, 5, 0, 0),
#  'MostRecentOrderDate': datetime.datetime(1998, 4, 14, 0, 0),
#  'TotalOrders': 86,
#  'TotalQuantityPurchased': 3961,
#  'TotalRevenue': 117483.39,
#  '_id': ObjectId('69330f83d829b3b4c31d4da6')}
